# %% [markdown]
# ### Imports

# %%
# Visualization
import matplotlib.pyplot as plt

# Data related libraries
import numpy as np
import pandas as pd

# Parameters handling libraries
from sklearn.model_selection import GridSearchCV

# Classifiers
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier

# Metrics
from sklearn import metrics
from sklearn.model_selection import train_test_split

# Neural Networks
import tensorflow as tf
from sklearn.preprocessing import MinMaxScaler
from keras.utils import to_categorical

# %%
gpus = tf.config.list_physical_devices('GPU')
if gpus:
    print('GPU is available and will be used.')
else:
    print('GPU is not available. Falling back to CPU.')
# Out:
# GPU is not available. Falling back to CPU.

# %% [markdown]
# ### Configuration

# %%
EXPERIMENT = "tara"
ACTIVITIES = ["relaxing", "eating", "walking", "studying"]

# %% [markdown]
# ### Dataset

# %%
def check_missing_values(dataset: pd.DataFrame, dataset_identifier: str):
    # Check if there are any remaining missing values
    missing_values = dataset.isnull().sum().sum()
    if missing_values > 0:
        print(f"There are still {missing_values} missing values in the [{dataset_identifier}]")
    else:
        print(f"All missing values have been filled in the [{dataset_identifier}]")

# %%
def fill_missing_data(dataset: pd.DataFrame):
    # Forward fill
    dataset = dataset.fillna(method='ffill')  
    # backward fill missing values
    dataset = dataset.fillna(method='bfill')
    return dataset

# %%
source_directory = "final_datasets/reduced_features/"

# Loading `train` data
train_dataset = pd.read_csv(f"{source_directory}/{EXPERIMENT}_train_features.csv")
train_dataset.drop('time', axis=1, inplace=True) if 'time' in train_dataset.columns else None
check_missing_values(train_dataset, "train_dataset")
train_dataset = fill_missing_data(train_dataset)
check_missing_values(train_dataset, "train_dataset")
train_y = train_dataset[ACTIVITIES]
print("train_y", train_y.shape)
train_x = train_dataset.drop(ACTIVITIES, axis=1)
print("train_x", train_x.shape)

# Loading `validation` data
validation_dataset = pd.read_csv(f"{source_directory}/{EXPERIMENT}_validation.csv")
validation_dataset.drop('time', axis=1, inplace=True) if 'time' in validation_dataset.columns else None
check_missing_values(validation_dataset, "validation_dataset")
validation_dataset = fill_missing_data(validation_dataset)
check_missing_values(validation_dataset, "validation_dataset")
validation_y = validation_dataset[ACTIVITIES]
print("validation_y", validation_dataset.shape)
validation_x = validation_dataset.drop(ACTIVITIES, axis=1)
print("validation_x", validation_x.shape)

# Loading `test` data
test_dataset = pd.read_csv(f"{source_directory}/{EXPERIMENT}_test_features.csv")
test_dataset.drop('time', axis=1, inplace=True) if 'time' in test_dataset.columns else None
check_missing_values(test_dataset, "test_dataset")
test_dataset = fill_missing_data(test_dataset)
check_missing_values(test_dataset, "test_dataset")
test_y = test_dataset[ACTIVITIES]
print("test_y", test_y.shape)
test_x = test_dataset.drop(ACTIVITIES, axis=1)
print("test_x", test_x.shape)
# Out:
# All missing values have been filled in the [train_dataset]
# All missing values have been filled in the [train_dataset]
# train_y (20367, 4)
# train_x (20367, 13)
# All missing values have been filled in the [validation_dataset]
# All missing values have been filled in the [validation_dataset]
# validation_y (1200, 17)
# validation_x (1200, 13)
# All missing values have been filled in the [test_dataset]
# All missing values have been filled in the [test_dataset]
# test_y (3516, 4)
# test_x (3516, 13)

# %%
def compute_grid_search_result(model_instance, parameters, X, y):
    grid_search_instance = GridSearchCV(model_instance, parameters)
    return grid_search_instance.fit(X, y)

def compute_metrics(test_y: np.ndarray, predicted_y: np.ndarray):
    accuracy_score = metrics.accuracy_score(test_y, predicted_y)
    precision_score = metrics.precision_score(test_y, predicted_y, average=None)
    recall_score = metrics.recall_score(test_y, predicted_y, average=None)
    f1_score = metrics.f1_score(test_y, predicted_y, average=None)
    roc_auc_score = metrics.roc_auc_score(test_y, predicted_y, average=None)
    
    return {
        "accuracy_score": accuracy_score,
        "precision_score": precision_score,
        "recall_score": recall_score,
        "f1_score": f1_score,
        "roc_auc_score": roc_auc_score,
    }

def add_new_key_value_to_dict(dict, key, value):
    dict[key] = value
    return dict

def fit_predict_and_compute_metrics(
        model_definition: type,
        parameters: dict,
        train_x: pd.DataFrame,
        train_y: pd.DataFrame,
        test_x: pd.DataFrame,
        test_y: pd.DataFrame
    ):

    model_instance: object = model_definition(**parameters)
    model_instance.fit(train_x, train_y)
    predicted_y: np.ndarray = model_instance.predict(test_x)
    metrics_result: dict = compute_metrics(test_y.values, predicted_y)
    return add_new_key_value_to_dict(metrics_result, "parameters", parameters)

# %%
def plot_results(results: dict, model_name: str):
    scores = {
        'Precision': results['precision_score'],
        'Recall': results['recall_score'],
        'F1-score': results['f1_score'],
        'Roc_auc_score': results['roc_auc_score']
    }

    _, ax = plt.subplots(figsize=(10, 6))
    bar_width = 0.2
    opacity = 0.8

    for i, (score_name, score_values) in enumerate(scores.items()):
        x = np.arange(len(score_values))
        bar_offset = i * bar_width
        ax.bar(x + bar_offset, score_values, bar_width, alpha=opacity, label=score_name)

    ax.set_xlabel('Activity')
    ax.set_ylabel('Score')
    ax.set_title(f'{model_name} Performance Metrics')
    ax.set_xticks(x)
    ax.set_xticklabels(ACTIVITIES)
    ax.legend()
    plt.tight_layout()
    plt.show()
    
    for activity, score_values in zip(ACTIVITIES, zip(*scores.values())):
        print(f'{activity}: {dict(zip(scores.keys(), score_values))}')

# %% [markdown]
# ## FeedForward neural network

# %% [markdown]
# ### Prepare data

# %%
def reshape_examples(data: np.array) -> np.array:
    return np.reshape(data, (data.shape[0], 1, data.shape[1]))

scaler: MinMaxScaler = MinMaxScaler()

# -------- TRAIN -------- #
train_x: np.array = scaler.fit_transform(train_x.to_numpy())
train_y: np.array = np.expand_dims(train_y.to_numpy(), axis=1)
train_x_reshaped = reshape_examples(train_x)

print("train_x.shape", train_x.shape)
print("train_y.shape", train_y.shape)
print("train_x_reshaped.shape", train_x_reshaped.shape)

# -------- VALIDATION -------- #
validation_x: np.array = scaler.fit_transform(validation_x.to_numpy())
validation_y: np.array = np.expand_dims(validation_y.to_numpy(), axis=1)
validation_x_reshaped = reshape_examples(validation_x)

print("validation_x.shape", validation_x.shape)
print("validation_y.shape", validation_y.shape)
print("validation_x_reshaped.shape", validation_x_reshaped.shape)

# -------- TEST -------- #
test_x: np.array = scaler.fit_transform(test_x.to_numpy())
test_y: np.array = np.expand_dims(test_y.to_numpy(), axis=1)
test_x_reshaped = reshape_examples(test_x)

print("test_x.shape", test_x.shape)
print("test_y.shape", test_y.shape)
print("test_x_reshaped.shape", test_x_reshaped.shape)

input_shape = (train_x_reshaped.shape[1:])
output_shape = train_y.shape[2]
print("input_shape", input_shape)
print("output_shape", output_shape)
# Out:
# train_x.shape (20367, 13)
# train_y.shape (20367, 1, 4)
# train_x_reshaped.shape (20367, 1, 13)
# validation_x.shape (1200, 13)
# validation_y.shape (1200, 1, 4)
# validation_x_reshaped.shape (1200, 1, 13)
# test_x.shape (3516, 13)
# test_y.shape (3516, 1, 4)
# test_x_reshaped.shape (3516, 1, 13)
# input_shape (1, 13)
# output_shape 4

# %% [markdown]
# ### Train

# %%
def build_ffnn_model(input_shape, output_shape, units, dropout, num_layers):
    model = tf.keras.Sequential()
    
    model.add(tf.keras.layers.Dense(units, input_shape=input_shape, activation='relu'))
    model.add(tf.keras.layers.Dropout(dropout))
    
    for _ in range(num_layers):
        model.add(tf.keras.layers.Dense(units, activation='relu'))
        model.add(tf.keras.layers.Dropout(dropout))
    
    model.add(tf.keras.layers.Dense(output_shape, activation='softmax'))
    
    model.compile(
        loss='categorical_crossentropy',
        optimizer='adam',
        metrics=[
            'accuracy',
            tf.keras.metrics.Precision(),
            tf.keras.metrics.Recall(),
        ]
    )

    return model

units=1000
dropout=0.1
epochs=25
batch_size=128
num_layers=10


model = build_ffnn_model(input_shape, output_shape, units, dropout, num_layers)
model.summary()
history = model.fit(
    train_x_reshaped, train_y,
    epochs=epochs, batch_size=batch_size,
    validation_data=(validation_x_reshaped, validation_y)
)   
print("history.history=", history.history)
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_15 (Dense)            (None, 1, 1000)           14000
#
#  dropout_12 (Dropout)        (None, 1, 1000)           0
#
#  dense_16 (Dense)            (None, 1, 1000)           1001000
#
#  dropout_13 (Dropout)        (None, 1, 1000)           0
#
#  dense_17 (Dense)            (None, 1, 1000)           1001000
#
#  dropout_14 (Dropout)        (None, 1, 1000)           0
#
#  dense_18 (Dense)            (None, 1, 1000)           1001000
#
#  dropout_15 (Dropout)        (None, 1, 1000)           0
#
#  dense_19 (Dense)            (None, 1, 1000)           1001000
#
#  dropout_16 (Dropout)        (None, 1, 1000)           0
#
#  dense_20 (Dense)            (None, 1, 1000)           1001000
#
#  dropout_17 (Dropout)        (None, 1, 1000)           0
#
#  dense_21 (Dense)            (None, 1, 1000)           1001000
#
#  dropout_18 (Dropout)        (None, 1, 1000)           0
#
#  dense_22 (Dense)            (None, 1, 1000)           1001000
#
#  dropout_19 (Dropout)        (None, 1, 1000)           0
#
#  dense_23 (Dense)            (None, 1, 1000)           1001000
#
#  dropout_20 (Dropout)        (None, 1, 1000)           0
#
#  dense_24 (Dense)            (None, 1, 1000)           1001000
#
#  dropout_21 (Dropout)        (None, 1, 1000)           0
#
#  dense_25 (Dense)            (None, 1, 1000)           1001000
#
#  dropout_22 (Dropout)        (None, 1, 1000)           0
#
#  dense_26 (Dense)            (None, 1, 4)              4004
#
# =================================================================
# Total params: 10,028,004
# Trainable params: 10,028,004
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/25
# 160/160 [==============================] - 25s 139ms/step - loss: 0.5108 - accuracy: 0.7517 - precision_2: 0.8682 - recall_2: 0.6721 - val_loss: 3.5209 - val_accuracy: 0.4125 - val_precision_2: 0.4113 - val_recall_2: 0.4075
# Epoch 2/25
# 160/160 [==============================] - 23s 142ms/step - loss: 0.2052 - accuracy: 0.9306 - precision_2: 0.9416 - recall_2: 0.9165 - val_loss: 0.9681 - val_accuracy: 0.8308 - val_precision_2: 0.8376 - val_recall_2: 0.8208
# Epoch 3/25
# 160/160 [==============================] - 22s 135ms/step - loss: 0.1546 - accuracy: 0.9533 - precision_2: 0.9559 - recall_2: 0.9504 - val_loss: 0.8409 - val_accuracy: 0.8217 - val_precision_2: 0.8222 - val_recall_2: 0.8208
# Epoch 4/25
# 160/160 [==============================] - 22s 135ms/step - loss: 0.1097 - accuracy: 0.9660 - precision_2: 0.9672 - recall_2: 0.9652 - val_loss: 1.3362 - val_accuracy: 0.8458 - val_precision_2: 0.8476 - val_recall_2: 0.8433
# Epoch 5/25
# 160/160 [==============================] - 21s 130ms/step - loss: 0.1178 - accuracy: 0.9643 - precision_2: 0.9649 - recall_2: 0.9632 - val_loss: 0.6022 - val_accuracy: 0.7117 - val_precision_2: 0.8974 - val_recall_2: 0.7067
# Epoch 6/25
# 160/160 [==============================] - 21s 130ms/step - loss: 0.1374 - accuracy: 0.9554 - precision_2: 0.9602 - recall_2: 0.9507 - val_loss: 1.8550 - val_accuracy: 0.8500 - val_precision_2: 0.8492 - val_recall_2: 0.8450
# Epoch 7/25
# 160/160 [==============================] - 21s 134ms/step - loss: 0.0798 - accuracy: 0.9732 - precision_2: 0.9738 - recall_2: 0.9725 - val_loss: 5.1985 - val_accuracy: 0.6650 - val_precision_2: 0.6667 - val_recall_2: 0.6650
# Epoch 8/25
# 160/160 [==============================] - 22s 136ms/step - loss: 0.0845 - accuracy: 0.9726 - precision_2: 0.9733 - recall_2: 0.9718 - val_loss: 0.9852 - val_accuracy: 0.8683 - val_precision_2: 0.8688 - val_recall_2: 0.8667
# Epoch 9/25
# 160/160 [==============================] - 21s 133ms/step - loss: 0.0826 - accuracy: 0.9730 - precision_2: 0.9734 - recall_2: 0.9723 - val_loss: 3.9340 - val_accuracy: 0.7675 - val_precision_2: 0.7656 - val_recall_2: 0.7567
# Epoch 10/25
# 160/160 [==============================] - 21s 133ms/step - loss: 0.1654 - accuracy: 0.9586 - precision_2: 0.9603 - recall_2: 0.9555 - val_loss: 2.4057 - val_accuracy: 0.7625 - val_precision_2: 0.7668 - val_recall_2: 0.7617
# Epoch 11/25
# 160/160 [==============================] - 21s 133ms/step - loss: 0.0925 - accuracy: 0.9715 - precision_2: 0.9727 - recall_2: 0.9704 - val_loss: 33.0138 - val_accuracy: 0.7842 - val_precision_2: 0.7844 - val_recall_2: 0.7792
# Epoch 12/25
# 160/160 [==============================] - 21s 133ms/step - loss: 0.1381 - accuracy: 0.9600 - precision_2: 0.9616 - recall_2: 0.9578 - val_loss: 1.5978 - val_accuracy: 0.8083 - val_precision_2: 0.8098 - val_recall_2: 0.7983
# Epoch 13/25
# 160/160 [==============================] - 21s 133ms/step - loss: 0.0926 - accuracy: 0.9704 - precision_2: 0.9718 - recall_2: 0.9692 - val_loss: 27.3571 - val_accuracy: 0.8492 - val_precision_2: 0.8492 - val_recall_2: 0.8492
# Epoch 14/25
# 160/160 [==============================] - 21s 132ms/step - loss: 0.1462 - accuracy: 0.9552 - precision_2: 0.9567 - recall_2: 0.9543 - val_loss: 23.2753 - val_accuracy: 0.8075 - val_precision_2: 0.8082 - val_recall_2: 0.8075
# Epoch 15/25
# 160/160 [==============================] - 21s 132ms/step - loss: 0.1087 - accuracy: 0.9674 - precision_2: 0.9682 - recall_2: 0.9666 - val_loss: 2.3416 - val_accuracy: 0.8467 - val_precision_2: 0.8467 - val_recall_2: 0.8467
# Epoch 16/25
# 160/160 [==============================] - 21s 132ms/step - loss: 0.0767 - accuracy: 0.9766 - precision_2: 0.9769 - recall_2: 0.9763 - val_loss: 27.8250 - val_accuracy: 0.7842 - val_precision_2: 0.7840 - val_recall_2: 0.7833
# Epoch 17/25
# 160/160 [==============================] - 21s 134ms/step - loss: 0.1078 - accuracy: 0.9667 - precision_2: 0.9681 - recall_2: 0.9657 - val_loss: 70.5769 - val_accuracy: 0.7883 - val_precision_2: 0.7882 - val_recall_2: 0.7875
# Epoch 18/25
# 160/160 [==============================] - 20s 124ms/step - loss: 0.0766 - accuracy: 0.9731 - precision_2: 0.9740 - recall_2: 0.9721 - val_loss: 114.2749 - val_accuracy: 0.8025 - val_precision_2: 0.8096 - val_recall_2: 0.7975
# Epoch 19/25
# 160/160 [==============================] - 20s 122ms/step - loss: 0.0720 - accuracy: 0.9762 - precision_2: 0.9775 - recall_2: 0.9749 - val_loss: 60.8848 - val_accuracy: 0.7883 - val_precision_2: 0.7961 - val_recall_2: 0.7775
# Epoch 20/25
# 160/160 [==============================] - 20s 123ms/step - loss: 0.0514 - accuracy: 0.9822 - precision_2: 0.9826 - recall_2: 0.9815 - val_loss: 144.1472 - val_accuracy: 0.7425 - val_precision_2: 0.7420 - val_recall_2: 0.7358
# Epoch 21/25
# 160/160 [==============================] - 20s 123ms/step - loss: 0.0661 - accuracy: 0.9803 - precision_2: 0.9810 - recall_2: 0.9795 - val_loss: 2.7046 - val_accuracy: 0.8467 - val_precision_2: 0.8462 - val_recall_2: 0.8342
# Epoch 22/25
# 160/160 [==============================] - 20s 123ms/step - loss: 0.1035 - accuracy: 0.9671 - precision_2: 0.9677 - recall_2: 0.9664 - val_loss: 9.1840 - val_accuracy: 0.7933 - val_precision_2: 0.7953 - val_recall_2: 0.7933
# Epoch 23/25
# 160/160 [==============================] - 20s 124ms/step - loss: 0.0780 - accuracy: 0.9739 - precision_2: 0.9746 - recall_2: 0.9731 - val_loss: 9.4331 - val_accuracy: 0.8475 - val_precision_2: 0.8495 - val_recall_2: 0.8467
# Epoch 24/25
# 160/160 [==============================] - 20s 123ms/step - loss: 0.0904 - accuracy: 0.9733 - precision_2: 0.9748 - recall_2: 0.9724 - val_loss: 5.6951 - val_accuracy: 0.8608 - val_precision_2: 0.8765 - val_recall_2: 0.8575
# Epoch 25/25
# 160/160 [==============================] - 20s 123ms/step - loss: 0.1176 - accuracy: 0.9648 - precision_2: 0.9680 - recall_2: 0.9602 - val_loss: 5.2782 - val_accuracy: 0.7958 - val_precision_2: 0.7986 - val_recall_2: 0.7867
# history.history= {'loss': [0.5107570290565491, 0.20524537563323975, 0.1546081006526947, 0.10971839725971222, 0.11779095232486725, 0.13744251430034637, 0.07976093143224716, 0.0844917967915535, 0.08259586989879608, 0.16537964344024658, 0.0925433486700058, 0.13814783096313477, 0.09264984726905823, 0.14620555937290192, 0.10869914293289185, 0.0767240896821022, 0.10776838660240173, 0.0766303539276123, 0.07198404520750046, 0.05143166333436966, 0.06607259809970856, 0.10353796929121017, 0.0780479907989502, 0.09035057574510574, 0.11762534826993942], 'accuracy': [0.7517061829566956, 0.9306230545043945, 0.9532577395439148, 0.9660234451293945, 0.9643049836158752, 0.955418050289154, 0.9731919169425964, 0.9725536704063416, 0.9729955196380615, 0.9586095213890076, 0.9715225696563721, 0.959984302520752, 0.9703933000564575, 0.955172598361969, 0.9673982262611389, 0.9765797853469849, 0.9666617512702942, 0.9731428027153015, 0.976186990737915, 0.9821770787239075, 0.9802621603012085, 0.967054545879364, 0.9739283919334412, 0.9732901453971863, 0.9648451209068298], 'precision_2': [0.8681973814964294, 0.9415888786315918, 0.955854058265686, 0.9671832919120789, 0.9648812413215637, 0.9602281451225281, 0.973795473575592, 0.9732507467269897, 0.9734060764312744, 0.9602763652801514, 0.9727335572242737, 0.961646556854248, 0.9718379378318787, 0.956684410572052, 0.9681813716888428, 0.9769087433815002, 0.9680578708648682, 0.9740247130393982, 0.9775009751319885, 0.9825509786605835, 0.9810189008712769, 0.9677451252937317, 0.9745771288871765, 0.9748461842536926, 0.9679750800132751], 'recall_2': [0.6720675826072693, 0.9165316224098206, 0.9504099488258362, 0.9651888012886047, 0.9631757140159607, 0.9507045745849609, 0.9725045561790466, 0.971817135810852, 0.9722590446472168, 0.955467164516449, 0.9703933000564575, 0.957774817943573, 0.9691658020019531, 0.9542887806892395, 0.9666126370429993, 0.9762851595878601, 0.9657288789749146, 0.9721117615699768, 0.9748613238334656, 0.9814896583557129, 0.9795256853103638, 0.9663671851158142, 0.9730937480926514, 0.9723572731018066, 0.9601806998252869], 'val_loss': [3.520890712738037, 0.968083918094635, 0.8408772945404053, 1.3361729383468628, 0.6022188067436218, 1.8549662828445435, 5.198471546173096, 0.9852201342582703, 3.9340193271636963, 2.4056904315948486, 33.01384353637695, 1.5977745056152344, 27.35710906982422, 23.275306701660156, 2.3416244983673096, 27.824968338012695, 70.57688903808594, 114.27493286132812, 60.88483810424805, 144.14715576171875, 2.7046186923980713, 9.184001922607422, 9.433115005493164, 5.695112705230713, 5.278171539306641], 'val_accuracy': [0.4124999940395355, 0.8308333158493042, 0.8216666579246521, 0.8458333611488342, 0.7116666436195374, 0.8500000238418579, 0.6650000214576721, 0.8683333396911621, 0.7674999833106995, 0.762499988079071, 0.784166693687439, 0.8083333373069763, 0.8491666913032532, 0.8075000047683716, 0.846666693687439, 0.784166693687439, 0.7883333563804626, 0.8025000095367432, 0.7883333563804626, 0.7425000071525574, 0.846666693687439, 0.7933333516120911, 0.8475000262260437, 0.8608333468437195, 0.7958333492279053], 'val_precision_2': [0.4112699627876282, 0.8375850319862366, 0.8222036957740784, 0.8475711941719055, 0.8973544836044312, 0.8492462038993835, 0.6666666865348816, 0.8688387870788574, 0.7655986547470093, 0.7667785286903381, 0.7843959927558899, 0.8098055720329285, 0.8491666913032532, 0.8081734776496887, 0.846666693687439, 0.7839866280555725, 0.7881568074226379, 0.8096446990966797, 0.7960751056671143, 0.7420167922973633, 0.8461538553237915, 0.7953216433525085, 0.8494983315467834, 0.8764906525611877, 0.7986463904380798], 'val_recall_2': [0.4074999988079071, 0.8208333253860474, 0.8208333253860474, 0.8433333039283752, 0.7066666483879089, 0.8450000286102295, 0.6650000214576721, 0.8666666746139526, 0.7566666603088379, 0.7616666555404663, 0.7791666388511658, 0.7983333468437195, 0.8491666913032532, 0.8075000047683716, 0.846666693687439, 0.7833333611488342, 0.7875000238418579, 0.7975000143051147, 0.7774999 ...

# %%
# Plotting the training loss and validation loss
plt.figure(figsize=(12, 6))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.show()

# Plotting the training accuracy and validation accuracy
plt.figure(figsize=(12, 6))
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy')
plt.legend()
plt.show()


predicted_y = to_categorical(np.argmax(model.predict(test_x_reshaped).squeeze(axis=1), axis=1)).astype(int)
lstm_result: dict = compute_metrics(test_y.squeeze(axis=1), predicted_y)
plot_results(lstm_result, "FFNN")
# Out:
# 110/110 [==============================] - 2s 11ms/step
# relaxing: {'Precision': 0.32950191570881227, 'Recall': 0.4562334217506631, 'F1-score': 0.38264738598442716, 'Roc_auc_score': 0.5079909247118095}
# eating: {'Precision': 0.0, 'Recall': 0.0, 'F1-score': 0.0, 'Roc_auc_score': 0.4173014145810664}
# walking: {'Precision': 0.11885612153708669, 'Recall': 0.4618055555555556, 'F1-score': 0.1890547263681592, 'Roc_auc_score': 0.5781766315572078}
# studying: {'Precision': 0.028462998102466792, 'Recall': 0.03579952267303103, 'F1-score': 0.03171247357293869, 'Roc_auc_score': 0.4352391220081332}

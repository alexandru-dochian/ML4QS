# %% [markdown]
# ### Imports

# %%
# Visualization
import matplotlib.pyplot as plt

# Data related libraries
import numpy as np
import pandas as pd

# Parameters handling libraries
from sklearn.model_selection import GridSearchCV

# Classifiers
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier

# Metrics
from sklearn import metrics
from sklearn.model_selection import train_test_split

# Neural Networks
import tensorflow as tf
from sklearn.preprocessing import MinMaxScaler
from keras.utils import to_categorical

# %%
gpus = tf.config.list_physical_devices('GPU')
if gpus:
    print('GPU is available and will be used.')
else:
    print('GPU is not available. Falling back to CPU.')
# Out:
# GPU is not available. Falling back to CPU.

# %% [markdown]
# ### Configuration

# %%
EXPERIMENT = "tara"
ACTIVITIES = ["relaxing", "eating", "walking", "studying"]

# %% [markdown]
# ### Dataset

# %%
def check_missing_values(dataset: pd.DataFrame, dataset_identifier: str):
    # Check if there are any remaining missing values
    missing_values = dataset.isnull().sum().sum()
    if missing_values > 0:
        print(f"There are still {missing_values} missing values in the [{dataset_identifier}]")
    else:
        print(f"All missing values have been filled in the [{dataset_identifier}]")

# %%
def fill_missing_data(dataset: pd.DataFrame):
    # Forward fill
    dataset = dataset.fillna(method='ffill')  
    # backward fill missing values
    dataset = dataset.fillna(method='bfill')
    return dataset

# %%
source_directory = "final_datasets/all_features/"

# Loading `train` data
train_dataset = pd.read_csv(f"{source_directory}/{EXPERIMENT}_train_features.csv")
train_dataset.drop('time', axis=1, inplace=True) if 'time' in train_dataset.columns else None
check_missing_values(train_dataset, "train_dataset")
train_dataset = fill_missing_data(train_dataset)
check_missing_values(train_dataset, "train_dataset")
train_y = train_dataset[ACTIVITIES]
print("train_y", train_y.shape)
train_x = train_dataset.drop(ACTIVITIES, axis=1)
print("train_x", train_x.shape)

# Loading `validation` data
validation_dataset = pd.read_csv(f"{source_directory}/{EXPERIMENT}_validation.csv")
validation_dataset.drop('time', axis=1, inplace=True) if 'time' in validation_dataset.columns else None
check_missing_values(validation_dataset, "validation_dataset")
validation_dataset = fill_missing_data(validation_dataset)
check_missing_values(validation_dataset, "validation_dataset")
validation_y = validation_dataset[ACTIVITIES]
print("validation_y", validation_dataset.shape)
validation_x = validation_dataset.drop(ACTIVITIES, axis=1)
print("validation_x", validation_x.shape)

# Loading `test` data
test_dataset = pd.read_csv(f"{source_directory}/{EXPERIMENT}_test_features.csv")
test_dataset.drop('time', axis=1, inplace=True) if 'time' in test_dataset.columns else None
check_missing_values(test_dataset, "test_dataset")
test_dataset = fill_missing_data(test_dataset)
check_missing_values(test_dataset, "test_dataset")
test_y = test_dataset[ACTIVITIES]
print("test_y", test_y.shape)
test_x = test_dataset.drop(ACTIVITIES, axis=1)
print("test_x", test_x.shape)
# Out:
# There are still 8811 missing values in the [train_dataset]
# All missing values have been filled in the [train_dataset]
# train_y (20396, 4)
# train_x (20396, 1056)
# All missing values have been filled in the [validation_dataset]
# All missing values have been filled in the [validation_dataset]
# validation_y (1200, 1060)
# validation_x (1200, 1056)
# There are still 8811 missing values in the [test_dataset]
# All missing values have been filled in the [test_dataset]
# test_y (3545, 4)
# test_x (3545, 1056)

# %%
def compute_grid_search_result(model_instance, parameters, X, y):
    grid_search_instance = GridSearchCV(model_instance, parameters)
    return grid_search_instance.fit(X, y)

def compute_metrics(test_y: np.ndarray, predicted_y: np.ndarray):
    accuracy_score = metrics.accuracy_score(test_y, predicted_y)
    precision_score = metrics.precision_score(test_y, predicted_y, average=None)
    recall_score = metrics.recall_score(test_y, predicted_y, average=None)
    f1_score = metrics.f1_score(test_y, predicted_y, average=None)
    roc_auc_score = metrics.roc_auc_score(test_y, predicted_y, average=None)
    
    return {
        "accuracy_score": accuracy_score,
        "precision_score": precision_score,
        "recall_score": recall_score,
        "f1_score": f1_score,
        "roc_auc_score": roc_auc_score,
    }

def add_new_key_value_to_dict(dict, key, value):
    dict[key] = value
    return dict

def fit_predict_and_compute_metrics(
        model_definition: type,
        parameters: dict,
        train_x: pd.DataFrame,
        train_y: pd.DataFrame,
        test_x: pd.DataFrame,
        test_y: pd.DataFrame
    ):

    model_instance: object = model_definition(**parameters)
    model_instance.fit(train_x, train_y)
    predicted_y: np.ndarray = model_instance.predict(test_x)
    metrics_result: dict = compute_metrics(test_y.values, predicted_y)
    return add_new_key_value_to_dict(metrics_result, "parameters", parameters)

# %%
def plot_results(results: dict, model_name: str):
    scores = {
        'Precision': results['precision_score'],
        'Recall': results['recall_score'],
        'F1-score': results['f1_score'],
        'Roc_auc_score': results['roc_auc_score']
    }

    _, ax = plt.subplots(figsize=(10, 6))
    bar_width = 0.2
    opacity = 0.8

    for i, (score_name, score_values) in enumerate(scores.items()):
        x = np.arange(len(score_values))
        bar_offset = i * bar_width
        ax.bar(x + bar_offset, score_values, bar_width, alpha=opacity, label=score_name)

    ax.set_xlabel('Activity')
    ax.set_ylabel('Score')
    ax.set_title(f'{model_name} Performance Metrics')
    ax.set_xticks(x)
    ax.set_xticklabels(ACTIVITIES)
    ax.legend()
    plt.tight_layout()
    plt.show()
    
    for activity, score_values in zip(ACTIVITIES, zip(*scores.values())):
        print(f'{activity}: {dict(zip(scores.keys(), score_values))}')

# %% [markdown]
# ## LSTM

# %% [markdown]
# ### Prepare data

# %%
def create_windows(train_x, train_y, window_size):
    num_samples = train_x.shape[0]
    num_features = train_x.shape[1]
    num_classes = train_y.shape[1]
    
    num_windows = num_samples // window_size

    train_x_windows = np.empty((num_windows, window_size, num_features))
    train_y_windows = np.empty((num_windows, num_classes))
    
    for i in range(num_windows):
        start_idx = i * window_size
        end_idx = start_idx + window_size
        
        train_x_windows[i] = train_x[start_idx:end_idx]
        
        window_classes, class_counts = np.unique(train_y[start_idx:end_idx], axis=0, return_counts=True)
        max_count_idx = np.argmax(class_counts)
        
        train_y_windows[i] = window_classes[max_count_idx]
        
    return train_x_windows, train_y_windows

# %%
window_size = 30
scaler: MinMaxScaler = MinMaxScaler()

# -------- TRAIN -------- #
train_x: np.array = scaler.fit_transform(train_x.to_numpy())
train_y: np.array = train_y.to_numpy()

print("train_x.shape", train_x.shape)
print("train_y.shape", train_y.shape)

train_x, train_y = create_windows(train_x, train_y, window_size)
print("After reshape> train_x.shape", train_x.shape)
print("After reshape> train_y.shape", train_y.shape)


# -------- VALIDATION -------- #
validation_x: np.array = scaler.fit_transform(validation_x.to_numpy())
validation_y: np.array = validation_y.to_numpy()

print("validation_x.shape", validation_x.shape)
print("validation_y.shape", validation_y.shape)

validation_x, validation_y = create_windows(validation_x, validation_y, window_size)
print("After reshape> validation_x.shape", validation_x.shape)
print("After reshape> validation_y.shape", validation_y.shape)

# -------- TEST -------- #
test_x: np.array = scaler.fit_transform(test_x.to_numpy())
test_y: np.array = test_y.to_numpy()

print("test_x.shape", test_x.shape)
print("test_y.shape", test_y.shape)
test_x, test_y = create_windows(test_x, test_y, window_size)
print("After reshape> test_x.shape", test_x.shape)
print("After reshape> test_y.shape", test_y.shape)

input_shape = (train_x.shape[1:])
output_shape = train_y.shape[1]
# Out:
# train_x.shape (20396, 1056)
# train_y.shape (20396, 4)
# After reshape> train_x.shape (679, 30, 1056)
# After reshape> train_y.shape (679, 4)
# validation_x.shape (1200, 1056)
# validation_y.shape (1200, 4)
# After reshape> validation_x.shape (40, 30, 1056)
# After reshape> validation_y.shape (40, 4)
# test_x.shape (3545, 1056)
# test_y.shape (3545, 4)
# After reshape> test_x.shape (118, 30, 1056)
# After reshape> test_y.shape (118, 4)

# %% [markdown]
# ### Train

# %%
def build_lstm_model(input_shape, output_shape, units, dropout):
    model = tf.keras.Sequential()
    
    model.add(tf.keras.layers.LSTM(units, input_shape=input_shape, return_sequences=True))
    model.add(tf.keras.layers.Dropout(dropout))
    
    model.add(tf.keras.layers.LSTM(units))
    model.add(tf.keras.layers.Dropout(dropout))
    
    model.add(tf.keras.layers.Dense(units, activation='relu'))
    
    model.add(tf.keras.layers.Dense(units, activation='relu'))
    
    model.add(tf.keras.layers.Dense(output_shape, activation='softmax'))
    
    model.compile(
        loss='categorical_crossentropy',
        optimizer='adam',
        metrics=[
            'accuracy',
            tf.keras.metrics.Precision(),
            tf.keras.metrics.Recall(),
        ]
    )

    return model

units=1000
dropout=0.5
epochs=25
batch_size=8


model = build_lstm_model(input_shape, output_shape, units, dropout)
model.summary()
history = model.fit(
    train_x, train_y,
    epochs=epochs, batch_size=batch_size,
    validation_data=(validation_x, validation_y)
)   
print("history.history=", history.history)
# Out:
# 2023-06-25 21:37:12.614354: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 30, 1000)          8228000
#
#  dropout (Dropout)           (None, 30, 1000)          0
#
#  lstm_1 (LSTM)               (None, 1000)              8004000
#
#  dropout_1 (Dropout)         (None, 1000)              0
#
#  dense (Dense)               (None, 1000)              1001000
#
#  dense_1 (Dense)             (None, 1000)              1001000
#
#  dense_2 (Dense)             (None, 4)                 4004
#
# =================================================================
# Total params: 18,238,004
# Trainable params: 18,238,004
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/25
# 85/85 [==============================] - 104s 1s/step - loss: 1.2310 - accuracy: 0.4197 - precision: 0.4080 - recall: 0.2091 - val_loss: 1.9544 - val_accuracy: 0.2500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 2/25
# 85/85 [==============================] - 94s 1s/step - loss: 1.0973 - accuracy: 0.4286 - precision: 0.4228 - recall: 0.1694 - val_loss: 1.0797 - val_accuracy: 0.4250 - val_precision: 0.4737 - val_recall: 0.2250
# Epoch 3/25
# 85/85 [==============================] - 94s 1s/step - loss: 0.9199 - accuracy: 0.4845 - precision: 0.5030 - recall: 0.3711 - val_loss: 1.0552 - val_accuracy: 0.4750 - val_precision: 0.4737 - val_recall: 0.4500
# Epoch 4/25
# 85/85 [==============================] - 96s 1s/step - loss: 0.8574 - accuracy: 0.4713 - precision: 0.4898 - recall: 0.3873 - val_loss: 0.9225 - val_accuracy: 0.4000 - val_precision: 0.6000 - val_recall: 0.3750
# Epoch 5/25
# 85/85 [==============================] - 94s 1s/step - loss: 0.7513 - accuracy: 0.5331 - precision: 0.5363 - recall: 0.4786 - val_loss: 0.9466 - val_accuracy: 0.5000 - val_precision: 0.4737 - val_recall: 0.4500
# Epoch 6/25
# 85/85 [==============================] - 95s 1s/step - loss: 0.7478 - accuracy: 0.5538 - precision: 0.5672 - recall: 0.5037 - val_loss: 1.1045 - val_accuracy: 0.2750 - val_precision: 0.3929 - val_recall: 0.2750
# Epoch 7/25
# 85/85 [==============================] - 95s 1s/step - loss: 0.7553 - accuracy: 0.5479 - precision: 0.5336 - recall: 0.4566 - val_loss: 1.5719 - val_accuracy: 0.5000 - val_precision: 0.4872 - val_recall: 0.4750
# Epoch 8/25
# 85/85 [==============================] - 95s 1s/step - loss: 0.7087 - accuracy: 0.5641 - precision: 0.5602 - recall: 0.5140 - val_loss: 0.9019 - val_accuracy: 0.5750 - val_precision: 0.6250 - val_recall: 0.5000
# Epoch 9/25
# 85/85 [==============================] - 95s 1s/step - loss: 0.6800 - accuracy: 0.5876 - precision: 0.5961 - recall: 0.5803 - val_loss: 0.9057 - val_accuracy: 0.5000 - val_precision: 0.5333 - val_recall: 0.4000
# Epoch 10/25
# 85/85 [==============================] - 96s 1s/step - loss: 0.6719 - accuracy: 0.5832 - precision: 0.5798 - recall: 0.5670 - val_loss: 1.0508 - val_accuracy: 0.3500 - val_precision: 0.3590 - val_recall: 0.3500
# Epoch 11/25
# 85/85 [==============================] - 95s 1s/step - loss: 0.6686 - accuracy: 0.6230 - precision: 0.6361 - recall: 0.6127 - val_loss: 2.3809 - val_accuracy: 0.2250 - val_precision: 0.2250 - val_recall: 0.2250
# Epoch 12/25
# 85/85 [==============================] - 95s 1s/step - loss: 0.6354 - accuracy: 0.6406 - precision: 0.6428 - recall: 0.6333 - val_loss: 1.8407 - val_accuracy: 0.4000 - val_precision: 0.4000 - val_recall: 0.4000
# Epoch 13/25
# 85/85 [==============================] - 94s 1s/step - loss: 0.6023 - accuracy: 0.7172 - precision: 0.7182 - recall: 0.6981 - val_loss: 1.1667 - val_accuracy: 0.4500 - val_precision: 0.4571 - val_recall: 0.4000
# Epoch 14/25
# 85/85 [==============================] - 91s 1s/step - loss: 0.4781 - accuracy: 0.7968 - precision: 0.8109 - recall: 0.7894 - val_loss: 1.5973 - val_accuracy: 0.6000 - val_precision: 0.6562 - val_recall: 0.5250
# Epoch 15/25
# 85/85 [==============================] - 91s 1s/step - loss: 0.3086 - accuracy: 0.8792 - precision: 0.8836 - recall: 0.8719 - val_loss: 1.9712 - val_accuracy: 0.6500 - val_precision: 0.6500 - val_recall: 0.6500
# Epoch 16/25
# 85/85 [==============================] - 91s 1s/step - loss: 0.3147 - accuracy: 0.8866 - precision: 0.8921 - recall: 0.8763 - val_loss: 1.6550 - val_accuracy: 0.5250 - val_precision: 0.5385 - val_recall: 0.5250
# Epoch 17/25
# 85/85 [==============================] - 92s 1s/step - loss: 0.3746 - accuracy: 0.8733 - precision: 0.8789 - recall: 0.8660 - val_loss: 1.5636 - val_accuracy: 0.5250 - val_precision: 0.5250 - val_recall: 0.5250
# Epoch 18/25
# 85/85 [==============================] - 91s 1s/step - loss: 0.2605 - accuracy: 0.9028 - precision: 0.9070 - recall: 0.8910 - val_loss: 1.1853 - val_accuracy: 0.6750 - val_precision: 0.6000 - val_recall: 0.4500
# Epoch 19/25
# 85/85 [==============================] - 91s 1s/step - loss: 0.1974 - accuracy: 0.9323 - precision: 0.9374 - recall: 0.9264 - val_loss: 2.4373 - val_accuracy: 0.5250 - val_precision: 0.5250 - val_recall: 0.5250
# Epoch 20/25
# 85/85 [==============================] - 91s 1s/step - loss: 0.1330 - accuracy: 0.9411 - precision: 0.9408 - recall: 0.9367 - val_loss: 1.3760 - val_accuracy: 0.5750 - val_precision: 0.5641 - val_recall: 0.5500
# Epoch 21/25
# 85/85 [==============================] - 94s 1s/step - loss: 0.1903 - accuracy: 0.9426 - precision: 0.9480 - recall: 0.9396 - val_loss: 1.6246 - val_accuracy: 0.6000 - val_precision: 0.6053 - val_recall: 0.5750
# Epoch 22/25
# 85/85 [==============================] - 99s 1s/step - loss: 0.1662 - accuracy: 0.9381 - precision: 0.9435 - recall: 0.9337 - val_loss: 2.6775 - val_accuracy: 0.7250 - val_precision: 0.7179 - val_recall: 0.7000
# Epoch 23/25
# 85/85 [==============================] - 129s 2s/step - loss: 0.2200 - accuracy: 0.9234 - precision: 0.9337 - recall: 0.9131 - val_loss: 1.2053 - val_accuracy: 0.7250 - val_precision: 0.7297 - val_recall: 0.6750
# Epoch 24/25
# 85/85 [==============================] - 128s 2s/step - loss: 0.1271 - accuracy: 0.9485 - precision: 0.9512 - recall: 0.9470 - val_loss: 1.1746 - val_accuracy: 0.7000 - val_precision: 0.6923 - val_recall: 0.6750
# Epoch 25/25
# 85/85 [==============================] - 123s 1s/step - loss: 0.2310 - accuracy: 0.9043 - precision: 0.9269 - recall: 0.8969 - val_loss: 0.9445 - val_accuracy: 0.5750 - val_precision: 0.5882 - val_recall: 0.5000
# history.history= {'loss': [1.231009840965271, 1.0972788333892822, 0.9199206233024597, 0.8573769330978394, 0.7512518763542175, 0.7477523684501648, 0.7552847862243652, 0.7087352275848389, 0.6799609065055847, 0.6719170212745667, 0.6686387062072754, 0.6354304552078247, 0.6023326516151428, 0.4781164824962616, 0.3086409568786621, 0.3147396445274353, 0.3746054768562317, 0.26053470373153687, 0.19739441573619843, 0.13295909762382507, 0.1903252750635147, 0.16615144908428192, 0.22003819048404694, 0.12711559236049652, 0.23100675642490387], 'accuracy': [0.4197348952293396, 0.4285714328289032, 0.4845360815525055, 0.4712812900543213, 0.5331369638442993, 0.553755521774292, 0.5478644967079163, 0.5640648007392883, 0.5876288414001465, 0.5832105875015259, 0.6229749917984009, 0.6406480073928833, 0.7172312140464783, 0.7967599630355835, 0.8792341947555542, 0.8865979313850403, 0.8733431696891785, 0.9027982354164124, 0.9322533011436462, 0.9410898089408875, 0.9425625801086426, 0.938144326210022, 0.923416793346405, 0.9484536051750183, 0.9042710065841675], 'precision': [0.4080459773540497, 0.4227941036224365, 0.5029940009117126, 0.4897579252719879, 0.5363036394119263, 0.5671641826629639, 0.5335628390312195, 0.5601926445960999, 0.5960665941238403, 0.5798192620277405, 0.6360856294631958, 0.6427503824234009, 0.7181817889213562, 0.8108925819396973, 0.8835821151733398, 0.8920539617538452, 0.878923773765564, 0.9070464968681335, 0.9374068379402161, 0.9408283829689026, 0.9479940533638, 0.9434523582458496, 0.9337349534034729, 0.9511834383010864, 0.9269406199455261], 'recall': [0.20913107693195343, 0.169366717338562, 0.3711340129375458, 0.38733431696891785, 0.47864505648612976, 0.5036818981170654, 0.45655375719070435, 0.5139911770820618, 0.5802651047706604, 0.5670102834701538, 0.6126657128334045, 0.6332842707633972, 0.6980854272842407, 0.7893961668014526, 0.8718703985214233, 0.876288652420044, 0.8659793734550476, 0.8910161852836609, 0.9263622760772705, 0.9366715550422668, 0.9396170973777771, 0.9337260723114014, 0.9131075143814087, 0.9469808340072632, 0.8969072103500366], 'val_loss': [1.9544408321380615, 1.0797208547592163, 1.0551658868789673, 0.922481894493103, 0.9465948343276978, 1.1045085191726685, 1.5718870162963867, 0.9019231796264648, 0.905704140663147, 1.0507721900939941, 2.3809432983398438, 1.8406797647476196, 1.1666887998580933, 1.5972540378570557, 1.971240758895874, 1.6550260782241821, 1.5636155605316162, 1.1852972507476807, 2.4373109340667725, 1.375961184501648, 1.6245825290679932, 2.677544116973877, 1.2053344249725342, 1.174641489982605, 0.9444527626037598], 'val_accuracy': [0.25, 0.42500001192092896, 0.4749999940395355, 0.4000000059604645, 0.5, 0.2750000059604645, 0.5, 0.574999988079071, 0.5, 0.3499999940395355, 0.22499999403953552, 0.4000000059604645, 0.44999998807907104, 0.6000000238418579, 0.6499999761581421, 0.5249999761581421, 0.5249999761581421, 0.675000011920929, 0.5249999761581421, 0.574999988079071, 0.6000000238418579, 0.7250000238418579, 0.7250000238418579, 0.699999988079071, 0.574999988079071], 'val_precision': [0.0, 0.4736842215061188, 0.4736842215061188, 0.6000000238418579, 0.4736842215061188, 0.3928571343421936, 0.4871794879436493, 0.625, 0.5333333611488342, 0.3589743673801422, 0.22499999403953552, 0.4000000059604645, 0.4571428596973419, 0.65625, 0.6499999761581421, 0.5384615659713745, 0.5249999761581421, 0.6000000238418579, 0.5249999761581421, 0.5641025900840759, 0.6052631735801697, 0.7179487347602844, 0.7297297120094299, 0.692307710647583, 0.5882353186607361], 'val_recall': [0.0, 0.22499999403953552, 0.44999998807907104, 0.375, 0.44999998807907104, 0.2750000059604645, 0.4749999940395355, 0.5, 0.4000000059604645, 0.3499999940395355, 0.22499999403953552, 0.4000000059604645, 0.4000000059604645, 0.5249999761581421, 0.6499999761581421, 0.5249999761581421, 0.5249999761581421, 0.44999998807907104, 0.5249999761581421, 0.550000011920929, 0.574999988079071, 0.699999988079071, 0.675000011920929, 0.675000011920929, 0.5]}

# %%
# Plotting the training loss and validation loss
plt.figure(figsize=(12, 6))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.show()

# Plotting the training accuracy and validation accuracy
plt.figure(figsize=(12, 6))
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy')
plt.legend()
plt.show()


predicted_y = to_categorical(np.argmax(model.predict(test_x), axis=1)).astype(int)
lstm_result: dict = compute_metrics(test_y, predicted_y)
plot_results(lstm_result, "LSTM")
# Out:
# 4/4 [==============================] - 2s 355ms/step
# relaxing: {'Precision': 0.0, 'Recall': 0.0, 'F1-score': 0.0, 'Roc_auc_score': 0.3888888888888889}
# eating: {'Precision': 0.5588235294117647, 'Recall': 0.6785714285714286, 'F1-score': 0.6129032258064516, 'Roc_auc_score': 0.5973502304147466}
# walking: {'Precision': 0.55, 'Recall': 1.0, 'F1-score': 0.7096774193548387, 'Roc_auc_score': 0.9579439252336448}
# studying: {'Precision': 0.0, 'Recall': 0.0, 'F1-score': 0.0, 'Roc_auc_score': 0.4423076923076923}

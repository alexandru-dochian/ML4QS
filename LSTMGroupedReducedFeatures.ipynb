# %% [markdown]
# ### Imports

# %%
# Visualization
import matplotlib.pyplot as plt

# Data related libraries
import numpy as np
import pandas as pd

# Parameters handling libraries
from sklearn.model_selection import GridSearchCV

# Classifiers
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier

# Metrics
from sklearn import metrics
from sklearn.model_selection import train_test_split

# Neural Networks
import tensorflow as tf
from sklearn.preprocessing import MinMaxScaler
from keras.utils import to_categorical

# %%
gpus = tf.config.list_physical_devices('GPU')
if gpus:
    print('GPU is available and will be used.')
else:
    print('GPU is not available. Falling back to CPU.')
# Out:
# GPU is not available. Falling back to CPU.

# %% [markdown]
# ### Configuration

# %%
EXPERIMENT = "tara"
ACTIVITIES = ["relaxing", "eating", "walking", "studying"]

# %% [markdown]
# ### Dataset

# %%
def check_missing_values(dataset: pd.DataFrame, dataset_identifier: str):
    # Check if there are any remaining missing values
    missing_values = dataset.isnull().sum().sum()
    if missing_values > 0:
        print(f"There are still {missing_values} missing values in the [{dataset_identifier}]")
    else:
        print(f"All missing values have been filled in the [{dataset_identifier}]")

# %%
def fill_missing_data(dataset: pd.DataFrame):
    # Forward fill
    dataset = dataset.fillna(method='ffill')  
    # backward fill missing values
    dataset = dataset.fillna(method='bfill')
    return dataset

# %%
source_directory = "final_datasets/reduced_features/"

# Loading `train` data
train_dataset = pd.read_csv(f"{source_directory}/{EXPERIMENT}_train_features.csv")
train_dataset.drop('time', axis=1, inplace=True) if 'time' in train_dataset.columns else None
check_missing_values(train_dataset, "train_dataset")
train_dataset = fill_missing_data(train_dataset)
check_missing_values(train_dataset, "train_dataset")
train_y = train_dataset[ACTIVITIES]
print("train_y", train_y.shape)
train_x = train_dataset.drop(ACTIVITIES, axis=1)
print("train_x", train_x.shape)

# Loading `validation` data
validation_dataset = pd.read_csv(f"{source_directory}/{EXPERIMENT}_validation.csv")
validation_dataset.drop('time', axis=1, inplace=True) if 'time' in validation_dataset.columns else None
check_missing_values(validation_dataset, "validation_dataset")
validation_dataset = fill_missing_data(validation_dataset)
check_missing_values(validation_dataset, "validation_dataset")
validation_y = validation_dataset[ACTIVITIES]
print("validation_y", validation_dataset.shape)
validation_x = validation_dataset.drop(ACTIVITIES, axis=1)
print("validation_x", validation_x.shape)

# Loading `test` data
test_dataset = pd.read_csv(f"{source_directory}/{EXPERIMENT}_test_features.csv")
test_dataset.drop('time', axis=1, inplace=True) if 'time' in test_dataset.columns else None
check_missing_values(test_dataset, "test_dataset")
test_dataset = fill_missing_data(test_dataset)
check_missing_values(test_dataset, "test_dataset")
test_y = test_dataset[ACTIVITIES]
print("test_y", test_y.shape)
test_x = test_dataset.drop(ACTIVITIES, axis=1)
print("test_x", test_x.shape)
# Out:
# All missing values have been filled in the [train_dataset]
# All missing values have been filled in the [train_dataset]
# train_y (20367, 4)
# train_x (20367, 13)
# All missing values have been filled in the [validation_dataset]
# All missing values have been filled in the [validation_dataset]
# validation_y (1200, 17)
# validation_x (1200, 13)
# All missing values have been filled in the [test_dataset]
# All missing values have been filled in the [test_dataset]
# test_y (3516, 4)
# test_x (3516, 13)

# %%
def compute_grid_search_result(model_instance, parameters, X, y):
    grid_search_instance = GridSearchCV(model_instance, parameters)
    return grid_search_instance.fit(X, y)

def compute_metrics(test_y: np.ndarray, predicted_y: np.ndarray):
    accuracy_score = metrics.accuracy_score(test_y, predicted_y)
    precision_score = metrics.precision_score(test_y, predicted_y, average=None)
    recall_score = metrics.recall_score(test_y, predicted_y, average=None)
    f1_score = metrics.f1_score(test_y, predicted_y, average=None)
    roc_auc_score = metrics.roc_auc_score(test_y, predicted_y, average=None)
    
    return {
        "accuracy_score": accuracy_score,
        "precision_score": precision_score,
        "recall_score": recall_score,
        "f1_score": f1_score,
        "roc_auc_score": roc_auc_score,
    }

def add_new_key_value_to_dict(dict, key, value):
    dict[key] = value
    return dict

def fit_predict_and_compute_metrics(
        model_definition: type,
        parameters: dict,
        train_x: pd.DataFrame,
        train_y: pd.DataFrame,
        test_x: pd.DataFrame,
        test_y: pd.DataFrame
    ):

    model_instance: object = model_definition(**parameters)
    model_instance.fit(train_x, train_y)
    predicted_y: np.ndarray = model_instance.predict(test_x)
    metrics_result: dict = compute_metrics(test_y.values, predicted_y)
    return add_new_key_value_to_dict(metrics_result, "parameters", parameters)

# %%
def plot_results(results: dict, model_name: str):
    scores = {
        'Precision': results['precision_score'],
        'Recall': results['recall_score'],
        'F1-score': results['f1_score'],
        'Roc_auc_score': results['roc_auc_score']
    }

    _, ax = plt.subplots(figsize=(10, 6))
    bar_width = 0.2
    opacity = 0.8

    for i, (score_name, score_values) in enumerate(scores.items()):
        x = np.arange(len(score_values))
        bar_offset = i * bar_width
        ax.bar(x + bar_offset, score_values, bar_width, alpha=opacity, label=score_name)

    ax.set_xlabel('Activity')
    ax.set_ylabel('Score')
    ax.set_title(f'{model_name} Performance Metrics')
    ax.set_xticks(x)
    ax.set_xticklabels(ACTIVITIES)
    ax.legend()
    plt.tight_layout()
    plt.show()
    
    for activity, score_values in zip(ACTIVITIES, zip(*scores.values())):
        print(f'{activity}: {dict(zip(scores.keys(), score_values))}')

# %% [markdown]
# ## LSTM

# %% [markdown]
# ### Prepare data

# %%
def create_windows(train_x, train_y, window_size):
    num_samples = train_x.shape[0]
    num_features = train_x.shape[1]
    num_classes = train_y.shape[1]
    
    num_windows = num_samples // window_size

    train_x_windows = np.empty((num_windows, window_size, num_features))
    train_y_windows = np.empty((num_windows, num_classes))
    
    for i in range(num_windows):
        start_idx = i * window_size
        end_idx = start_idx + window_size
        
        train_x_windows[i] = train_x[start_idx:end_idx]
        
        window_classes, class_counts = np.unique(train_y[start_idx:end_idx], axis=0, return_counts=True)
        max_count_idx = np.argmax(class_counts)
        
        train_y_windows[i] = window_classes[max_count_idx]
        
    return train_x_windows, train_y_windows

# %%
window_size = 5
scaler: MinMaxScaler = MinMaxScaler()

# -------- TRAIN -------- #
train_x: np.array = scaler.fit_transform(train_x.to_numpy())
train_y: np.array = train_y.to_numpy()

print("train_x.shape", train_x.shape)
print("train_y.shape", train_y.shape)

train_x, train_y = create_windows(train_x, train_y, window_size)
print("After reshape> train_x.shape", train_x.shape)
print("After reshape> train_y.shape", train_y.shape)


# -------- VALIDATION -------- #
validation_x: np.array = scaler.fit_transform(validation_x.to_numpy())
validation_y: np.array = validation_y.to_numpy()

print("validation_x.shape", validation_x.shape)
print("validation_y.shape", validation_y.shape)

validation_x, validation_y = create_windows(validation_x, validation_y, window_size)
print("After reshape> validation_x.shape", validation_x.shape)
print("After reshape> validation_y.shape", validation_y.shape)

# -------- TEST -------- #
test_x: np.array = scaler.fit_transform(test_x.to_numpy())
test_y: np.array = test_y.to_numpy()

print("test_x.shape", test_x.shape)
print("test_y.shape", test_y.shape)
test_x, test_y = create_windows(test_x, test_y, window_size)
print("After reshape> test_x.shape", test_x.shape)
print("After reshape> test_y.shape", test_y.shape)

input_shape = (train_x.shape[1:])
output_shape = train_y.shape[1]
# Out:
# train_x.shape (20367, 13)
# train_y.shape (20367, 4)
# After reshape> train_x.shape (4073, 5, 13)
# After reshape> train_y.shape (4073, 4)
# validation_x.shape (1200, 13)
# validation_y.shape (1200, 4)
# After reshape> validation_x.shape (240, 5, 13)
# After reshape> validation_y.shape (240, 4)
# test_x.shape (3516, 13)
# test_y.shape (3516, 4)
# After reshape> test_x.shape (703, 5, 13)
# After reshape> test_y.shape (703, 4)

# %% [markdown]
# ### Train

# %%
def build_lstm_model(input_shape, output_shape, units, dropout):
    model = tf.keras.Sequential()
    
    model.add(tf.keras.layers.LSTM(units, input_shape=input_shape, return_sequences=True))
    model.add(tf.keras.layers.Dropout(dropout))
    
    model.add(tf.keras.layers.LSTM(units))
    model.add(tf.keras.layers.Dropout(dropout))
    
    model.add(tf.keras.layers.Dense(units, activation='relu'))
    
    model.add(tf.keras.layers.Dense(units, activation='relu'))
    
    model.add(tf.keras.layers.Dense(output_shape, activation='softmax'))
    
    model.compile(
        loss='categorical_crossentropy',
        optimizer='adam',
        metrics=[
            'accuracy',
            tf.keras.metrics.Precision(),
            tf.keras.metrics.Recall(),
        ]
    )

    return model

units=500
dropout=0.05
epochs=25
batch_size=8


model = build_lstm_model(input_shape, output_shape, units, dropout)
model.summary()
history = model.fit(
    train_x, train_y,
    epochs=epochs, batch_size=batch_size,
    validation_data=(validation_x, validation_y)
)   
print("history.history=", history.history)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_1 (LSTM)               (None, 5, 500)            1028000
#
#  dropout_1 (Dropout)         (None, 5, 500)            0
#
#  lstm_2 (LSTM)               (None, 500)               2002000
#
#  dropout_2 (Dropout)         (None, 500)               0
#
#  dense_2 (Dense)             (None, 500)               250500
#
#  dense_3 (Dense)             (None, 500)               250500
#
#  dense_4 (Dense)             (None, 4)                 2004
#
# =================================================================
# Total params: 3,533,004
# Trainable params: 3,533,004
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/25
# 510/510 [==============================] - 39s 69ms/step - loss: 0.4912 - accuracy: 0.7916 - precision_1: 0.8370 - recall_1: 0.7439 - val_loss: 1.5457 - val_accuracy: 0.5583 - val_precision_1: 0.5678 - val_recall_1: 0.5583
# Epoch 2/25
# 510/510 [==============================] - 36s 71ms/step - loss: 0.2866 - accuracy: 0.9025 - precision_1: 0.9093 - recall_1: 0.8907 - val_loss: 1.1993 - val_accuracy: 0.7708 - val_precision_1: 0.7741 - val_recall_1: 0.7708
# Epoch 3/25
# 510/510 [==============================] - 35s 68ms/step - loss: 0.2460 - accuracy: 0.9141 - precision_1: 0.9195 - recall_1: 0.9082 - val_loss: 0.4175 - val_accuracy: 0.9000 - val_precision_1: 0.9000 - val_recall_1: 0.9000
# Epoch 4/25
# 510/510 [==============================] - 34s 68ms/step - loss: 0.2132 - accuracy: 0.9317 - precision_1: 0.9335 - recall_1: 0.9300 - val_loss: 0.8922 - val_accuracy: 0.7042 - val_precision_1: 0.7161 - val_recall_1: 0.7042
# Epoch 5/25
# 510/510 [==============================] - 34s 67ms/step - loss: 0.1986 - accuracy: 0.9403 - precision_1: 0.9433 - recall_1: 0.9389 - val_loss: 0.6876 - val_accuracy: 0.8083 - val_precision_1: 0.8178 - val_recall_1: 0.8042
# Epoch 6/25
# 510/510 [==============================] - 35s 68ms/step - loss: 0.1704 - accuracy: 0.9457 - precision_1: 0.9478 - recall_1: 0.9443 - val_loss: 1.1030 - val_accuracy: 0.7667 - val_precision_1: 0.7706 - val_recall_1: 0.7417
# Epoch 7/25
# 510/510 [==============================] - 35s 68ms/step - loss: 0.1698 - accuracy: 0.9438 - precision_1: 0.9467 - recall_1: 0.9418 - val_loss: 0.4467 - val_accuracy: 0.8792 - val_precision_1: 0.8782 - val_recall_1: 0.8708
# Epoch 8/25
# 510/510 [==============================] - 34s 68ms/step - loss: 0.1603 - accuracy: 0.9504 - precision_1: 0.9518 - recall_1: 0.9497 - val_loss: 0.9865 - val_accuracy: 0.7250 - val_precision_1: 0.7269 - val_recall_1: 0.7208
# Epoch 9/25
# 510/510 [==============================] - 34s 67ms/step - loss: 0.1554 - accuracy: 0.9499 - precision_1: 0.9522 - recall_1: 0.9479 - val_loss: 1.0105 - val_accuracy: 0.7708 - val_precision_1: 0.7741 - val_recall_1: 0.7708
# Epoch 10/25
# 510/510 [==============================] - 34s 67ms/step - loss: 0.1573 - accuracy: 0.9536 - precision_1: 0.9579 - recall_1: 0.9494 - val_loss: 0.5027 - val_accuracy: 0.8375 - val_precision_1: 0.8445 - val_recall_1: 0.8375
# Epoch 11/25
# 510/510 [==============================] - 34s 67ms/step - loss: 0.1738 - accuracy: 0.9440 - precision_1: 0.9468 - recall_1: 0.9396 - val_loss: 0.4944 - val_accuracy: 0.8042 - val_precision_1: 0.8042 - val_recall_1: 0.8042
# Epoch 12/25
# 510/510 [==============================] - 29s 58ms/step - loss: 0.1395 - accuracy: 0.9538 - precision_1: 0.9558 - recall_1: 0.9511 - val_loss: 1.0488 - val_accuracy: 0.8417 - val_precision_1: 0.8481 - val_recall_1: 0.8375
# Epoch 13/25
# 510/510 [==============================] - 29s 58ms/step - loss: 0.1462 - accuracy: 0.9543 - precision_1: 0.9552 - recall_1: 0.9534 - val_loss: 0.4242 - val_accuracy: 0.8875 - val_precision_1: 0.8875 - val_recall_1: 0.8875
# Epoch 14/25
# 510/510 [==============================] - 34s 67ms/step - loss: 0.1211 - accuracy: 0.9610 - precision_1: 0.9630 - recall_1: 0.9595 - val_loss: 0.8746 - val_accuracy: 0.8833 - val_precision_1: 0.8974 - val_recall_1: 0.8750
# Epoch 15/25
# 510/510 [==============================] - 30s 59ms/step - loss: 0.1596 - accuracy: 0.9470 - precision_1: 0.9508 - recall_1: 0.9443 - val_loss: 0.8013 - val_accuracy: 0.8375 - val_precision_1: 0.8368 - val_recall_1: 0.8333
# Epoch 16/25
# 510/510 [==============================] - 30s 58ms/step - loss: 0.1172 - accuracy: 0.9583 - precision_1: 0.9596 - recall_1: 0.9568 - val_loss: 1.6349 - val_accuracy: 0.8208 - val_precision_1: 0.8235 - val_recall_1: 0.8167
# Epoch 17/25
# 510/510 [==============================] - 33s 65ms/step - loss: 0.1393 - accuracy: 0.9551 - precision_1: 0.9591 - recall_1: 0.9509 - val_loss: 0.9702 - val_accuracy: 0.8333 - val_precision_1: 0.8368 - val_recall_1: 0.8333
# Epoch 18/25
# 510/510 [==============================] - 34s 67ms/step - loss: 0.1016 - accuracy: 0.9654 - precision_1: 0.9673 - recall_1: 0.9649 - val_loss: 1.4662 - val_accuracy: 0.8167 - val_precision_1: 0.8167 - val_recall_1: 0.8167
# Epoch 19/25
# 510/510 [==============================] - 34s 67ms/step - loss: 0.1397 - accuracy: 0.9573 - precision_1: 0.9595 - recall_1: 0.9546 - val_loss: 0.7961 - val_accuracy: 0.8125 - val_precision_1: 0.8255 - val_recall_1: 0.8083
# Epoch 20/25
# 510/510 [==============================] - 34s 67ms/step - loss: 0.1188 - accuracy: 0.9644 - precision_1: 0.9656 - recall_1: 0.9637 - val_loss: 1.0459 - val_accuracy: 0.8292 - val_precision_1: 0.8277 - val_recall_1: 0.8208
# Epoch 21/25
# 510/510 [==============================] - 33s 65ms/step - loss: 0.1121 - accuracy: 0.9617 - precision_1: 0.9633 - recall_1: 0.9612 - val_loss: 1.0414 - val_accuracy: 0.8125 - val_precision_1: 0.8112 - val_recall_1: 0.7875
# Epoch 22/25
# 510/510 [==============================] - 33s 65ms/step - loss: 0.1118 - accuracy: 0.9617 - precision_1: 0.9635 - recall_1: 0.9600 - val_loss: 1.0084 - val_accuracy: 0.8125 - val_precision_1: 0.8159 - val_recall_1: 0.8125
# Epoch 23/25
# 510/510 [==============================] - 35s 68ms/step - loss: 0.0931 - accuracy: 0.9671 - precision_1: 0.9685 - recall_1: 0.9659 - val_loss: 2.2548 - val_accuracy: 0.6167 - val_precision_1: 0.6192 - val_recall_1: 0.6167
# Epoch 24/25
# 510/510 [==============================] - 35s 69ms/step - loss: 0.1209 - accuracy: 0.9619 - precision_1: 0.9640 - recall_1: 0.9597 - val_loss: 1.0167 - val_accuracy: 0.8458 - val_precision_1: 0.8481 - val_recall_1: 0.8375
# Epoch 25/25
# 510/510 [==============================] - 34s 66ms/step - loss: 0.0945 - accuracy: 0.9659 - precision_1: 0.9668 - recall_1: 0.9646 - val_loss: 1.6159 - val_accuracy: 0.8042 - val_precision_1: 0.8042 - val_recall_1: 0.8042
# history.history= {'loss': [0.4912489056587219, 0.28657522797584534, 0.24602371454238892, 0.21323440968990326, 0.1985664814710617, 0.1703992336988449, 0.16980481147766113, 0.16033123433589935, 0.15535792708396912, 0.1572769284248352, 0.1738050878047943, 0.13954123854637146, 0.14620979130268097, 0.12110333889722824, 0.15956129133701324, 0.11717310547828674, 0.13930372893810272, 0.10155032575130463, 0.13968198001384735, 0.11884231120347977, 0.11213438957929611, 0.11184503883123398, 0.09313605725765228, 0.12094184756278992, 0.09445808082818985], 'accuracy': [0.7915541529655457, 0.9025288224220276, 0.9140682816505432, 0.9317456483840942, 0.9403387904167175, 0.9457402229309082, 0.9437760710716248, 0.9504051208496094, 0.9499140977859497, 0.953596830368042, 0.9440215826034546, 0.9538424015045166, 0.9543334245681763, 0.9609624147415161, 0.9469678401947021, 0.9582617282867432, 0.9550699591636658, 0.9653818011283875, 0.957279622554779, 0.9643996953964233, 0.9616990089416504, 0.9616990089416504, 0.9671004414558411, 0.9619445204734802, 0.9658728241920471], 'precision_1': [0.8370165824890137, 0.9092732071876526, 0.9194630980491638, 0.933464765548706, 0.9432659149169922, 0.9477575421333313, 0.9466930031776428, 0.9517716765403748, 0.9521578550338745, 0.9578894972801208, 0.9468085169792175, 0.9558351635932922, 0.9552275538444519, 0.9630360007286072, 0.9508034586906433, 0.9596158862113953, 0.9591382145881653, 0.9672655463218689, 0.9595261812210083, 0.9655596613883972, 0.9633365869522095, 0.9635288119316101, 0.9684884548187256, 0.9639950394630432, 0.966781497001648], 'recall_1': [0.7439234256744385, 0.8907439112663269, 0.9081757664680481, 0.9300270080566406, 0.9388657212257385, 0.9442671537399292, 0.9418119192123413, 0.9496685266494751, 0.9479498863220215, 0.9494230151176453, 0.939602255821228, 0.9511416554450989, 0.9533513188362122, 0.9594893455505371, 0.9442671537399292, 0.9567885994911194, 0.950896143913269, 0.964890718460083, 0.9545789361000061, 0.9636631608009338, 0.961207926273346, 0.9599803686141968, 0.9658728241920471, 0.9597348570823669, 0.9646452069282532], 'val_loss': [1.5457420349121094, 1.1992592811584473, 0.4174553155899048, 0.8922130465507507, 0.6876285076141357, 1.1030060052871704, 0.44668105244636536, 0.9864647388458252, 1.0104976892471313, 0.5026871562004089, 0.49442312121391296, 1.048809289932251, 0.42415571212768555, 0.8746458888053894, 0.8012830018997192, 1.6348549127578735, 0.9701586365699768, 1.4661978483200073, 0.7961012125015259, 1.0459272861480713, 1.0414398908615112, 1.0083717107772827, 2.254845142364502, 1.0166969299316406, 1.615949273109436], 'val_accuracy': [0.5583333373069763, 0.7708333134651184, 0.8999999761581421, 0.7041666507720947, 0.8083333373069763, 0.7666666507720947, 0.8791666626930237, 0.7250000238418579, 0.7708333134651184, 0.8374999761581421, 0.8041666746139526, 0.8416666388511658, 0.887499988079071, 0.8833333253860474, 0.8374999761581421, 0.8208333253860474, 0.8333333134651184, 0.8166666626930237, 0.8125, 0.8291666507720947, 0.8125, 0.8125, 0.6166666746139526, 0.8458333611488342, 0.8041666746139526], 'val_precision_1': [0.5677965879440308, 0.7740585803985596, 0.8999999761581421, 0.7161017060279846, 0.8177965879440308, 0.7705627679824829, 0.8781512379646301, 0.7268907427787781, 0.7740585803985596, 0.8445377945899963, 0.8041666746139526, 0.8481012582778931, 0.887499988079071, 0.8974359035491943, 0.8368200659751892, 0.8235294222831726, 0.8368200659751892, 0.8166666626930237, 0.8255318999290466, 0.8277310729026794, 0.8111587762832642, 0.8158996105194092, 0.6192468404769897, 0.8481012582778931, 0.8041666746139526], 'val_recall_1': [0.5583333373069763, 0.7708333134651184, 0.8999999761581421, 0.7041666507720947, 0.8041666746139526, 0.7416666746139526, 0.8708333373069763, 0.7208333611488342, 0.7708333134651184, 0.8374999761581421, 0.8041666746139526, 0.8374999761581421, 0.887499988079071, 0.875, 0.8333333134651184, 0.8166666626930237, 0.8333333134651184, 0.8166666626930237, 0.8083333373069763, 0.820833325386047 ...

# %%
# Plotting the training loss and validation loss
plt.figure(figsize=(12, 6))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.show()

# Plotting the training accuracy and validation accuracy
plt.figure(figsize=(12, 6))
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy')
plt.legend()
plt.show()


predicted_y = to_categorical(np.argmax(model.predict(test_x), axis=1)).astype(int)
lstm_result: dict = compute_metrics(test_y, predicted_y)
plot_results(lstm_result, "LSTM")
# Out:
# 22/22 [==============================] - 1s 19ms/step
# relaxing: {'Precision': 0.17682926829268292, 'Recall': 0.12831858407079647, 'F1-score': 0.14871794871794872, 'Roc_auc_score': 0.42264985807313415}
# eating: {'Precision': 0.0, 'Recall': 0.0, 'F1-score': 0.0, 'Roc_auc_score': 0.422554347826087}
# walking: {'Precision': 0.07541899441340782, 'Recall': 0.46551724137931033, 'F1-score': 0.12980769230769232, 'Roc_auc_score': 0.47616947340283344}
# studying: {'Precision': 0.0, 'Recall': 0.0, 'F1-score': 0.0, 'Roc_auc_score': 0.3998384491114701}

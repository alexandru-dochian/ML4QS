# %% [markdown]
# ### Imports

# %%
# Visualization
import matplotlib.pyplot as plt

# Data related libraries
import numpy as np
import pandas as pd

# Parameters handling libraries
from sklearn.model_selection import GridSearchCV

# Classifiers
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier

# Metrics
from sklearn import metrics
from sklearn.model_selection import train_test_split

# Neural Networks
import tensorflow as tf
from sklearn.preprocessing import MinMaxScaler
from keras.utils import to_categorical

# %%
gpus = tf.config.list_physical_devices('GPU')
if gpus:
    print('GPU is available and will be used.')
else:
    print('GPU is not available. Falling back to CPU.')
# Out:
# GPU is not available. Falling back to CPU.

# %% [markdown]
# ### Configuration

# %%
EXPERIMENT = "tara"
ACTIVITIES = ["relaxing", "eating", "walking", "studying"]

# %% [markdown]
# ### Dataset

# %%
def check_missing_values(dataset: pd.DataFrame, dataset_identifier: str):
    # Check if there are any remaining missing values
    missing_values = dataset.isnull().sum().sum()
    if missing_values > 0:
        print(f"There are still {missing_values} missing values in the [{dataset_identifier}]")
    else:
        print(f"All missing values have been filled in the [{dataset_identifier}]")

# %%
def fill_missing_data(dataset: pd.DataFrame):
    # Forward fill
    dataset = dataset.fillna(method='ffill')  
    # backward fill missing values
    dataset = dataset.fillna(method='bfill')
    return dataset

# %%
source_directory = "final_datasets/reduced_features/"

# Loading `train` data
train_dataset = pd.read_csv(f"{source_directory}/{EXPERIMENT}_train_features.csv")
train_dataset.drop('time', axis=1, inplace=True) if 'time' in train_dataset.columns else None
check_missing_values(train_dataset, "train_dataset")
train_dataset = fill_missing_data(train_dataset)
check_missing_values(train_dataset, "train_dataset")
train_y = train_dataset[ACTIVITIES]
print("train_y", train_y.shape)
train_x = train_dataset.drop(ACTIVITIES, axis=1)
print("train_x", train_x.shape)

# Loading `validation` data
validation_dataset = pd.read_csv(f"{source_directory}/{EXPERIMENT}_validation.csv")
validation_dataset.drop('time', axis=1, inplace=True) if 'time' in validation_dataset.columns else None
check_missing_values(validation_dataset, "validation_dataset")
validation_dataset = fill_missing_data(validation_dataset)
check_missing_values(validation_dataset, "validation_dataset")
validation_y = validation_dataset[ACTIVITIES]
print("validation_y", validation_dataset.shape)
validation_x = validation_dataset.drop(ACTIVITIES, axis=1)
print("validation_x", validation_x.shape)

# Loading `test` data
test_dataset = pd.read_csv(f"{source_directory}/{EXPERIMENT}_test_features.csv")
test_dataset.drop('time', axis=1, inplace=True) if 'time' in test_dataset.columns else None
check_missing_values(test_dataset, "test_dataset")
test_dataset = fill_missing_data(test_dataset)
check_missing_values(test_dataset, "test_dataset")
test_y = test_dataset[ACTIVITIES]
print("test_y", test_y.shape)
test_x = test_dataset.drop(ACTIVITIES, axis=1)
print("test_x", test_x.shape)
# Out:
# All missing values have been filled in the [train_dataset]
# All missing values have been filled in the [train_dataset]
# train_y (20367, 4)
# train_x (20367, 13)
# All missing values have been filled in the [validation_dataset]
# All missing values have been filled in the [validation_dataset]
# validation_y (1200, 17)
# validation_x (1200, 13)
# All missing values have been filled in the [test_dataset]
# All missing values have been filled in the [test_dataset]
# test_y (3516, 4)
# test_x (3516, 13)

# %%
def compute_grid_search_result(model_instance, parameters, X, y):
    grid_search_instance = GridSearchCV(model_instance, parameters)
    return grid_search_instance.fit(X, y)

def compute_metrics(test_y: np.ndarray, predicted_y: np.ndarray):
    accuracy_score = metrics.accuracy_score(test_y, predicted_y)
    precision_score = metrics.precision_score(test_y, predicted_y, average=None)
    recall_score = metrics.recall_score(test_y, predicted_y, average=None)
    f1_score = metrics.f1_score(test_y, predicted_y, average=None)
    roc_auc_score = metrics.roc_auc_score(test_y, predicted_y, average=None)
    
    return {
        "accuracy_score": accuracy_score,
        "precision_score": precision_score,
        "recall_score": recall_score,
        "f1_score": f1_score,
        "roc_auc_score": roc_auc_score,
    }

def add_new_key_value_to_dict(dict, key, value):
    dict[key] = value
    return dict

def fit_predict_and_compute_metrics(
        model_definition: type,
        parameters: dict,
        train_x: pd.DataFrame,
        train_y: pd.DataFrame,
        test_x: pd.DataFrame,
        test_y: pd.DataFrame
    ):

    model_instance: object = model_definition(**parameters)
    model_instance.fit(train_x, train_y)
    predicted_y: np.ndarray = model_instance.predict(test_x)
    metrics_result: dict = compute_metrics(test_y.values, predicted_y)
    return add_new_key_value_to_dict(metrics_result, "parameters", parameters)

# %%
def plot_results(results: dict, model_name: str):
    scores = {
        'Precision': results['precision_score'],
        'Recall': results['recall_score'],
        'F1-score': results['f1_score'],
        'Roc_auc_score': results['roc_auc_score']
    }

    _, ax = plt.subplots(figsize=(10, 6))
    bar_width = 0.2
    opacity = 0.8

    for i, (score_name, score_values) in enumerate(scores.items()):
        x = np.arange(len(score_values))
        bar_offset = i * bar_width
        ax.bar(x + bar_offset, score_values, bar_width, alpha=opacity, label=score_name)

    ax.set_xlabel('Activity')
    ax.set_ylabel('Score')
    ax.set_title(f'{model_name} Performance Metrics')
    ax.set_xticks(x)
    ax.set_xticklabels(ACTIVITIES)
    ax.legend()
    plt.tight_layout()
    plt.show()
    
    for activity, score_values in zip(ACTIVITIES, zip(*scores.values())):
        print(f'{activity}: {dict(zip(scores.keys(), score_values))}')

# %% [markdown]
# ## LSTM

# %% [markdown]
# ### Prepare data

# %%
def reshape_examples(data: np.array) -> np.array:
    return np.reshape(data, (data.shape[0], 1, data.shape[1]))

scaler: MinMaxScaler = MinMaxScaler()

# -------- TRAIN -------- #
train_x: np.array = scaler.fit_transform(train_x.to_numpy())
train_y: np.array = train_y.to_numpy()
train_x_reshaped = reshape_examples(train_x)

print("train_x.shape", train_x.shape)
print("train_y.shape", train_y.shape)
print("train_x_reshaped.shape", train_x_reshaped.shape)

# -------- VALIDATION -------- #
validation_x: np.array = scaler.fit_transform(validation_x.to_numpy())
validation_y: np.array = validation_y.to_numpy()
validation_x_reshaped = reshape_examples(validation_x)

print("validation_x.shape", validation_x.shape)
print("validation_y.shape", validation_y.shape)
print("validation_x_reshaped.shape", validation_x_reshaped.shape)

# -------- TEST -------- #
test_x: np.array = scaler.fit_transform(test_x.to_numpy())
test_y: np.array = test_y.to_numpy()
test_x_reshaped = reshape_examples(test_x)

print("test_x.shape", test_x.shape)
print("test_y.shape", test_y.shape)
print("test_x_reshaped.shape", test_x_reshaped.shape)

input_shape = (train_x_reshaped.shape[1:])
output_shape = train_y.shape[1]
print("input_shape", input_shape)
print("output_shape", output_shape)
# Out:
# train_x.shape (20367, 13)
# train_y.shape (20367, 4)
# train_x_reshaped.shape (20367, 1, 13)
# validation_x.shape (1200, 13)
# validation_y.shape (1200, 4)
# validation_x_reshaped.shape (1200, 1, 13)
# test_x.shape (3516, 13)
# test_y.shape (3516, 4)
# test_x_reshaped.shape (3516, 1, 13)
# input_shape (1, 13)
# output_shape 4

# %% [markdown]
# ### Train

# %%
def build_lstm_model(input_shape, output_shape, units, dropout):
    model = tf.keras.Sequential()
    
    model.add(tf.keras.layers.LSTM(units, input_shape=input_shape))
    model.add(tf.keras.layers.Dropout(dropout))
    
    model.add(tf.keras.layers.Dense(units, activation='relu'))
    
    model.add(tf.keras.layers.Dense(output_shape, activation='softmax'))
    
    model.compile(
        loss='categorical_crossentropy',
        optimizer='adam',
        metrics=[
            'accuracy',
            tf.keras.metrics.Precision(),
            tf.keras.metrics.Recall(),
        ]
    )

    return model

units=500
dropout=0.1
epochs=50
batch_size=256


model = build_lstm_model(input_shape, output_shape, units, dropout)
model.summary()
history = model.fit(
    train_x_reshaped, train_y,
    epochs=epochs, batch_size=batch_size,
    validation_data=(validation_x_reshaped, validation_y)
)   
print("history.history=", history.history)
# Out:
# Model: "sequential_15"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_15 (LSTM)              (None, 500)               1028000
#
#  dropout_13 (Dropout)        (None, 500)               0
#
#  dense_26 (Dense)            (None, 500)               250500
#
#  dense_27 (Dense)            (None, 4)                 2004
#
# =================================================================
# Total params: 1,280,504
# Trainable params: 1,280,504
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 80/80 [==============================] - 5s 36ms/step - loss: 0.8111 - accuracy: 0.6826 - precision_13: 0.8141 - recall_13: 0.4484 - val_loss: 0.5913 - val_accuracy: 0.7908 - val_precision_13: 0.8113 - val_recall_13: 0.6483
# Epoch 2/50
# 80/80 [==============================] - 2s 30ms/step - loss: 0.3256 - accuracy: 0.9088 - precision_13: 0.9255 - recall_13: 0.8741 - val_loss: 0.4189 - val_accuracy: 0.8583 - val_precision_13: 0.8792 - val_recall_13: 0.8125
# Epoch 3/50
# 80/80 [==============================] - 2s 30ms/step - loss: 0.2328 - accuracy: 0.9355 - precision_13: 0.9435 - recall_13: 0.9209 - val_loss: 0.3242 - val_accuracy: 0.8800 - val_precision_13: 0.8989 - val_recall_13: 0.8525
# Epoch 4/50
# 80/80 [==============================] - 2s 31ms/step - loss: 0.1936 - accuracy: 0.9488 - precision_13: 0.9527 - recall_13: 0.9419 - val_loss: 0.3263 - val_accuracy: 0.8850 - val_precision_13: 0.8883 - val_recall_13: 0.8750
# Epoch 5/50
# 80/80 [==============================] - 2s 30ms/step - loss: 0.1593 - accuracy: 0.9557 - precision_13: 0.9576 - recall_13: 0.9519 - val_loss: 0.4905 - val_accuracy: 0.8742 - val_precision_13: 0.8818 - val_recall_13: 0.8583
# Epoch 6/50
# 80/80 [==============================] - 3s 32ms/step - loss: 0.1393 - accuracy: 0.9612 - precision_13: 0.9625 - recall_13: 0.9596 - val_loss: 0.5233 - val_accuracy: 0.8592 - val_precision_13: 0.8690 - val_recall_13: 0.8567
# Epoch 7/50
# 80/80 [==============================] - 3s 39ms/step - loss: 0.1354 - accuracy: 0.9601 - precision_13: 0.9612 - recall_13: 0.9589 - val_loss: 0.6451 - val_accuracy: 0.8617 - val_precision_13: 0.8622 - val_recall_13: 0.8500
# Epoch 8/50
# 80/80 [==============================] - 3s 33ms/step - loss: 0.1244 - accuracy: 0.9620 - precision_13: 0.9634 - recall_13: 0.9615 - val_loss: 0.5862 - val_accuracy: 0.8650 - val_precision_13: 0.8679 - val_recall_13: 0.8542
# Epoch 9/50
# 80/80 [==============================] - 3s 32ms/step - loss: 0.1197 - accuracy: 0.9624 - precision_13: 0.9635 - recall_13: 0.9613 - val_loss: 0.6562 - val_accuracy: 0.8642 - val_precision_13: 0.8649 - val_recall_13: 0.8642
# Epoch 10/50
# 80/80 [==============================] - 3s 34ms/step - loss: 0.1223 - accuracy: 0.9617 - precision_13: 0.9627 - recall_13: 0.9607 - val_loss: 0.6829 - val_accuracy: 0.8650 - val_precision_13: 0.8663 - val_recall_13: 0.8642
# Epoch 11/50
# 80/80 [==============================] - 3s 32ms/step - loss: 0.1141 - accuracy: 0.9634 - precision_13: 0.9646 - recall_13: 0.9622 - val_loss: 0.8392 - val_accuracy: 0.8525 - val_precision_13: 0.8618 - val_recall_13: 0.8525
# Epoch 12/50
# 80/80 [==============================] - 3s 35ms/step - loss: 0.1092 - accuracy: 0.9654 - precision_13: 0.9667 - recall_13: 0.9645 - val_loss: 0.7111 - val_accuracy: 0.8667 - val_precision_13: 0.8666 - val_recall_13: 0.8658
# Epoch 13/50
# 80/80 [==============================] - 3s 35ms/step - loss: 0.1066 - accuracy: 0.9654 - precision_13: 0.9664 - recall_13: 0.9644 - val_loss: 0.7617 - val_accuracy: 0.8658 - val_precision_13: 0.8657 - val_recall_13: 0.8650
# Epoch 14/50
# 80/80 [==============================] - 3s 32ms/step - loss: 0.1035 - accuracy: 0.9651 - precision_13: 0.9660 - recall_13: 0.9643 - val_loss: 0.7764 - val_accuracy: 0.8658 - val_precision_13: 0.8657 - val_recall_13: 0.8650
# Epoch 15/50
# 80/80 [==============================] - 3s 36ms/step - loss: 0.1012 - accuracy: 0.9652 - precision_13: 0.9658 - recall_13: 0.9642 - val_loss: 0.7892 - val_accuracy: 0.8675 - val_precision_13: 0.8675 - val_recall_13: 0.8675
# Epoch 16/50
# 80/80 [==============================] - 3s 38ms/step - loss: 0.0951 - accuracy: 0.9667 - precision_13: 0.9672 - recall_13: 0.9664 - val_loss: 0.8875 - val_accuracy: 0.8633 - val_precision_13: 0.8648 - val_recall_13: 0.8633
# Epoch 17/50
# 80/80 [==============================] - 3s 38ms/step - loss: 0.0946 - accuracy: 0.9673 - precision_13: 0.9679 - recall_13: 0.9670 - val_loss: 0.8175 - val_accuracy: 0.8683 - val_precision_13: 0.8683 - val_recall_13: 0.8683
# Epoch 18/50
# 80/80 [==============================] - 3s 34ms/step - loss: 0.0911 - accuracy: 0.9681 - precision_13: 0.9684 - recall_13: 0.9675 - val_loss: 0.8075 - val_accuracy: 0.8683 - val_precision_13: 0.8683 - val_recall_13: 0.8683
# Epoch 19/50
# 80/80 [==============================] - 3s 33ms/step - loss: 0.0902 - accuracy: 0.9680 - precision_13: 0.9685 - recall_13: 0.9674 - val_loss: 0.8962 - val_accuracy: 0.8675 - val_precision_13: 0.8675 - val_recall_13: 0.8675
# Epoch 20/50
# 80/80 [==============================] - 3s 33ms/step - loss: 0.0861 - accuracy: 0.9693 - precision_13: 0.9696 - recall_13: 0.9687 - val_loss: 1.0917 - val_accuracy: 0.8317 - val_precision_13: 0.8317 - val_recall_13: 0.8317
# Epoch 21/50
# 80/80 [==============================] - 3s 34ms/step - loss: 0.0831 - accuracy: 0.9715 - precision_13: 0.9717 - recall_13: 0.9709 - val_loss: 1.0582 - val_accuracy: 0.8542 - val_precision_13: 0.8549 - val_recall_13: 0.8542
# Epoch 22/50
# 80/80 [==============================] - 3s 33ms/step - loss: 0.0818 - accuracy: 0.9700 - precision_13: 0.9704 - recall_13: 0.9698 - val_loss: 1.0128 - val_accuracy: 0.8617 - val_precision_13: 0.8617 - val_recall_13: 0.8617
# Epoch 23/50
# 80/80 [==============================] - 3s 34ms/step - loss: 0.0775 - accuracy: 0.9719 - precision_13: 0.9722 - recall_13: 0.9715 - val_loss: 1.1821 - val_accuracy: 0.8300 - val_precision_13: 0.8300 - val_recall_13: 0.8300
# Epoch 24/50
# 80/80 [==============================] - 3s 34ms/step - loss: 0.0780 - accuracy: 0.9725 - precision_13: 0.9728 - recall_13: 0.9723 - val_loss: 1.1511 - val_accuracy: 0.8517 - val_precision_13: 0.8515 - val_recall_13: 0.8508
# Epoch 25/50
# 80/80 [==============================] - 2s 30ms/step - loss: 0.0730 - accuracy: 0.9733 - precision_13: 0.9734 - recall_13: 0.9731 - val_loss: 1.1946 - val_accuracy: 0.8200 - val_precision_13: 0.8214 - val_recall_13: 0.8200
# Epoch 26/50
# 80/80 [==============================] - 2s 31ms/step - loss: 0.0711 - accuracy: 0.9736 - precision_13: 0.9738 - recall_13: 0.9734 - val_loss: 1.1409 - val_accuracy: 0.8633 - val_precision_13: 0.8633 - val_recall_13: 0.8633
# Epoch 27/50
# 80/80 [==============================] - 3s 32ms/step - loss: 0.0716 - accuracy: 0.9730 - precision_13: 0.9733 - recall_13: 0.9728 - val_loss: 1.2794 - val_accuracy: 0.8450 - val_precision_13: 0.8456 - val_recall_13: 0.8442
# Epoch 28/50
# 80/80 [==============================] - 2s 30ms/step - loss: 0.0687 - accuracy: 0.9749 - precision_13: 0.9750 - recall_13: 0.9748 - val_loss: 1.5741 - val_accuracy: 0.7500 - val_precision_13: 0.7580 - val_recall_13: 0.7492
# Epoch 29/50
# 80/80 [==============================] - 2s 28ms/step - loss: 0.0666 - accuracy: 0.9753 - precision_13: 0.9753 - recall_13: 0.9751 - val_loss: 1.3377 - val_accuracy: 0.8375 - val_precision_13: 0.8382 - val_recall_13: 0.8375
# Epoch 30/50
# 80/80 [==============================] - 2s 31ms/step - loss: 0.0628 - accuracy: 0.9769 - precision_13: 0.9771 - recall_13: 0.9767 - val_loss: 1.3333 - val_accuracy: 0.8475 - val_precision_13: 0.8496 - val_recall_13: 0.8475
# Epoch 31/50
# 80/80 [==============================] - 3s 31ms/step - loss: 0.0597 - accuracy: 0.9783 - precision_13: 0.9783 - recall_13: 0.9780 - val_loss: 1.5503 - val_accuracy: 0.7942 - val_precision_13: 0.7942 - val_recall_13: 0.7942
# Epoch 32/50
# 80/80 [==============================] - 3s 35ms/step - loss: 0.0571 - accuracy: 0.9795 - precision_13: 0.9796 - recall_13: 0.9793 - val_loss: 1.5565 - val_accuracy: 0.8133 - val_precision_13: 0.8151 - val_recall_13: 0.8117
# Epoch 33/50
# 80/80 [==============================] - 2s 30ms/step - loss: 0.0554 - accuracy: 0.9798 - precision_13: 0.9799 - recall_13: 0.9796 - val_loss: 1.5698 - val_accuracy: 0.8025 - val_precision_13: 0.8025 - val_recall_13: 0.8025
# Epoch 34/50
# 80/80 [==============================] - 2s 29ms/step - loss: 0.0547 - accuracy: 0.9801 - precision_13: 0.9802 - recall_13: 0.9799 - val_loss: 1.6107 - val_accuracy: 0.8033 - val_precision_13: 0.8043 - val_recall_13: 0.8017
# Epoch 35/50
# 80/80 [==============================] - 2s 30ms/step - loss: 0.0491 - accuracy: 0.9823 - precision_13: 0.9827 - recall_13: 0.9822 - val_loss: 1.4751 - val_accuracy: 0.8583 - val_precision_13: 0.8583 - val_recall_13: 0.8583
# Epoch 36/50
# 80/80 [==============================] - 2s 30ms/step - loss: 0.0488 - accuracy: 0.9833 - precision_13: 0.9833 - recall_13: 0.9830 - val_loss: 1.7785 - val_accuracy: 0.7658 - val_precision_13: 0.7658 - val_recall_13: 0.7658
# Epoch 37/50
# 80/80 [==============================] - 2s 29ms/step - loss: 0.0467 - accuracy: 0.9840 - precision_13: 0.9840 - recall_13: 0.9838 - val_loss: 1.9584 - val_accuracy: 0.7500 - val_precision_13: 0.7500 - val_recall_13: 0.7500
# Epoch 38/50
# 80/80 [==============================] - 3s 31ms/step - loss: 0.0465 - accuracy: 0.9838 - precision_13: 0.9839 - recall_13: 0.9837 - val_loss: 2.1462 - val_accuracy: 0.6967 - val_precision_13: 0.6964 - val_recall_13: 0.6958
# Epoch 39/50
# 80/80 [==============================] - 3s 32ms/step - loss: 0.0425 - accuracy: 0.9855 - precision_13: 0.9855 - recall_13: 0.9854 - val_loss: 1.7744 - val_accuracy: 0.8092 - val_precision_13: 0.8092 - val_recall_13: 0.8092
# Epoch 40/50
# 80/80 [==============================] - 3s 32ms/step - loss: 0.0392 - accuracy: 0.9864 - precision_13: 0.9865 - recall_13: 0.9864 - val_loss: 1.9466 - val_accuracy: 0.7633 - val_precision_13: 0.7633 - val_recall_13: 0.7633
# Epoch 41/50
# 80/80 [==============================] - 2s 30ms/step - loss: 0.0368 - accuracy: 0.9872 - precision_13: 0.9873 - recall_13: 0.9872 - val_loss: 1.8452 - val_accuracy: 0.7992 - val_precision_13: 0.7992 - val_recall_13: 0.7992
# Epoch 42/50
# 80/80 [==============================] - 2s 30ms/step - loss: 0.0340 - accuracy: 0.9878 - precision_13: 0.9879 - recall_13: 0.9876 - val_loss: 2.1875 - val_accuracy: 0.7617 - val_precision_13: 0.7694 - val_recall_13: 0.7617
# Epoch 43/50
# 80/80 [==============================] - 2s 30ms/step - loss: 0.0339 - accuracy: 0.9892 - precision_13: 0.9892 - recall_13: 0.9892 - val_loss: 1.8315 - val_accuracy: 0.7958 - val_precision_13: 0.7958 - val_recall_13: 0.7958
# Epoch 44/50
# 80/80 [==============================] - 2s 30ms/step - loss: 0.0337 - accuracy: 0.9884 - precision_13: 0.9884 - recall_13: 0.9883 - val_loss: 2.8167 - val_accuracy: 0.6208 - val_precision_13: 0.6208 - val_recall_13: 0.6208
# Epoch 45/50
# 80/80 [==============================] - 2s 30ms/step - loss: 0.0316 - accuracy: 0.9889 - precision_13: 0.9890 - recall_13: 0.9888 - val_loss: 2.0946 - val_accuracy: 0.7717 - val_precision_13: 0.7715 - val_recall_13: 0.7708
# Epoch 46/50
# 80/80 [==============================] - 2s 29ms/step - loss: 0.0290 - accuracy: 0.9898 - precision_13: 0.9898 - recall_13: 0.9897 - val_loss: 2.2102 - val_accuracy: 0.6750 - val_precision_13: 0.6750 - val_recall_13: 0.6750
# Epoch 47/50
# 80/80 [==============================] - 2s 31ms/step - loss: 0.0269 - accuracy: 0.9914 - precision_13: 0.9914 - recall_13: 0.9913 - val_loss: 2.0816 - val_accuracy: 0.7817 - val_precision_13: 0.7817 - val_recall_13: 0.7817
# Epoch 48/50
# 80/80 [==============================] - 2s 30ms/step - loss: 0.0243 - accuracy: 0.9923 - precision_13: 0.9923 - recall_13: 0.9923 - val_loss: 2.1559 - val_accuracy: 0.6917 - val_precision_13: 0.6917 - val_recall_13: 0.6917
# Epoch 49/50
# 80/80 [==============================] - 2s 29ms/step - loss: 0.0233 - accuracy: 0.9932 - precision_13: 0.9932 - recall_13: 0.9932 - val_loss: 2.0842 - val_accuracy: 0.7808 - val_precision_13: 0.7808 - val_recall_13: 0.7808
# Epoch 50/50
# 80/80 [==============================] - 2s 30ms/step - loss: 0.0239 - accuracy: 0.9922 - precision_13: 0.9922 - recall_13: 0.9921 - val_loss: 2.0448 - val_accuracy: 0.7808 - val_precision_13: 0.7820 - val_recall_13: 0.7800
# history.history= {'loss': [0.8111194968223572, 0.32555800676345825, 0.23275499045848846, 0.19364264607429504, 0.15932044386863708, 0.1392781138420105, 0.13541102409362793, 0.12440832704305649, 0.11973019689321518, 0.1222740188241005, 0.11406003683805466, 0.10923382639884949, 0.10655296593904495, 0.10345768183469772, 0.1012408658862114, 0.09505873918533325, 0.09461121261119843, 0.0911225825548172, 0.09021750837564468, 0.08608528226613998, 0.08309924602508545, 0.08180113881826401, 0.07745113968849182, 0.07804355770349503, 0.0730052962899208, 0.07108842581510544, 0.07158596068620682, 0.06870574504137039, 0.06656300276517868, 0.06283769011497498, 0.05969168245792389, 0.05711740627884865, 0.0553773008286953, 0.05470452830195427, 0.04914671555161476, 0.04884014278650284, 0.04673536866903305, 0.04653674736618996, 0.04253621771931648, 0.03919478505849838, 0.036760177463293076, 0.034014202654361725, 0.03386311233043671, 0.03373370319604874, 0.03161242976784706, 0.028992043808102608, 0.026888882741332054, 0.024263404309749603, 0.023287007585167885, 0.023874523118138313], 'accuracy': [0.6826238632202148, 0.9088230729103088, 0.9355329871177673, 0.9488388299942017, 0.9557126760482788, 0.9611626863479614, 0.960082471370697, 0.9619973301887512, 0.962390124797821, 0.9616536498069763, 0.9633721113204956, 0.9653851985931396, 0.9654342532157898, 0.9650905728340149, 0.9651888012886047, 0.9666617512702942, 0.9673491716384888, 0.9680856466293335, 0.9679874181747437, 0.969264030456543, 0.9714734554290771, 0.9700496196746826, 0.9719153642654419, 0.9724554419517517, 0.9733392000198364, 0.9736338257789612, 0.9730446338653564, 0.9749103784561157, 0.9752540588378906, 0.9768743515014648, 0.9782982468605042, 0.9794766306877136, 0.9798203110694885, 0.9800657629966736, 0.9823243618011475, 0.9832572340965271, 0.9839937090873718, 0.9837973117828369, 0.9854666590690613, 0.9863995909690857, 0.9872342348098755, 0.9877743124961853, 0.9892473220825195, 0.98836350440979, 0.9888545274734497, 0.9897873997688293, 0.9913585782051086, 0.9923405647277832, 0.9932243227958679, 0.9921932816505432], 'precision_13': [0.8140653967857361, 0.9254522919654846, 0.9435054063796997, 0.9526742100715637, 0.9576191902160645, 0.9624760150909424, 0.9611674547195435, 0.9634440541267395, 0.9634842276573181, 0.9627060294151306, 0.9645634293556213, 0.9667306542396545, 0.9664419889450073, 0.9659633040428162, 0.9658191204071045, 0.9671744704246521, 0.9679068326950073, 0.9684489965438843, 0.9685395359992981, 0.9696284532546997, 0.9716953039169312, 0.9703758358955383, 0.9721908569335938, 0.9728335738182068, 0.9734283089637756, 0.9738186597824097, 0.9732770323753357, 0.9750024676322937, 0.9753462076187134, 0.9770617485046387, 0.9783399105072021, 0.9796168804168701, 0.9798644781112671, 0.980206310749054, 0.9826603531837463, 0.9833496809005737, 0.9840396642684937, 0.9838915467262268, 0.9855143427848816, 0.9864957928657532, 0.9873305559158325, 0.9878689646720886, 0.9892473220825195, 0.9884109497070312, 0.9889505505561829, 0.9897869229316711, 0.9913577437400818, 0.9923405647277832, 0.993224024772644, 0.9921928644180298], 'recall_13': [0.4484214782714844, 0.8740609884262085, 0.9208523631095886, 0.9419158697128296, 0.9518829584121704, 0.959640622138977, 0.9588550329208374, 0.9614572525024414, 0.9612608551979065, 0.9607207775115967, 0.962242841720581, 0.96445232629776, 0.9643540978431702, 0.9642559289932251, 0.9642068147659302, 0.9663671851158142, 0.966956377029419, 0.9675455689430237, 0.9673982262611389, 0.9687238931655884, 0.9708842635154724, 0.9698041081428528, 0.9715225696563721, 0.9723081588745117, 0.9730937480926514, 0.9733883142471313, 0.9727991223335266, 0.9747630953788757, 0.9751067757606506, 0.9766779541969299, 0.9780036211013794, 0.9792802333831787, 0.9796239137649536, 0.9798694252967834, 0.9822261333465576, 0.9830117225646973, 0.9838464260101318, 0.9836500287055969, 0.9854176044464111, 0.9863504767417908, 0.9871851801872253, 0.9875779151916504, 0.9892473220825195, 0.988265335559845, 0.9887562 ...

# %%
# Plotting the training loss and validation loss
plt.figure(figsize=(12, 6))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.show()

# Plotting the training accuracy and validation accuracy
plt.figure(figsize=(12, 6))
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy')
plt.legend()
plt.show()


predicted_y = to_categorical(np.argmax(model.predict(test_x_reshaped), axis=1)).astype(int)
lstm_result: dict = compute_metrics(test_y, predicted_y)
plot_results(lstm_result, "LSTM")
# Out:
# 110/110 [==============================] - 1s 4ms/step
# relaxing: {'Precision': 0.3695652173913043, 'Recall': 0.34571175950486294, 'F1-score': 0.35724074920054816, 'Roc_auc_score': 0.5330235946371275}
# eating: {'Precision': 0.001201923076923077, 'Recall': 0.0005959475566150178, 'F1-score': 0.0007968127490039841, 'Roc_auc_score': 0.27423703797852517}
# walking: {'Precision': 0.004479283314669653, 'Recall': 0.013888888888888888, 'F1-score': 0.006773920406435224, 'Roc_auc_score': 0.3692430813713341}
# studying: {'Precision': 0.0, 'Recall': 0.0, 'F1-score': 0.0, 'Roc_auc_score': 0.3816596706490152}
